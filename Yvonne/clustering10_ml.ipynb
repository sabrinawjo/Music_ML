# %%
import pandas as pd

# %%
genre_artists = pd.read_csv("../Resources/clustering_data_preMLgenre.csv")
genre_artists.head()
# Out:
#                    id_artists                      id  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2  ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4  ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1       El Prisionero - Remasterizado           0       176907         0
# 2                 Lady of the Evening           0       163080         0
# 3                           Ave Maria           0       178933         0
# 4                             La Java           0       161427         0
#
#                artists release_date  danceability  energy  ...  acousticness  \
# 0  ['Ignacio Corsini']   1922-03-21         0.434  0.1770  ...         0.994
# ...

# %%
genre_artists.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'loudness_scale', 'tempo_scale',
#        'duration_scale', 'popularity_scale'],
#       dtype='object')

# %%
withGenre = pd.read_csv("../Resources/MLResources/cluster_genre_set.csv")
withGenre
# Out:
#                                                id_artists  \
# 0                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 1                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 2                              ['3BiJGZsyX9sJchTqcSA7Su']
# 3                              ['3BiJGZsyX9sJchTqcSA7Su']
# 4                              ['4AxgXfD7ISvJSTObqm4aIE']
# ...                                                   ...
# 549049                         ['1QLBXKM5GCpyQQSVMNZqrZ']
# 549050                         ['1dy5WNgIKQU6ezkpZs4y8z']
# 549051                         ['37M5pPGs6V1fchFJSgCguX']
# 549052  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...
# 549053                         ['0i4Qda0k4nf7jnNHmSNpYv']
#
#                             id                                name  \
# 0       07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 1       08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# ...

# %%
for column in withGenre:
    if "DistancesToClusterCenter" in column:
        withGenre.drop(column, axis=1, inplace=True)
withGenre.to_csv("../Resources/MLResources/cluster_genre_set.csv")

# %%
withGenre["artists"] = withGenre.artists.str.strip("[]")
withGenre["artists"] = withGenre.artists.str.split(", ")
withGenre = withGenre.explode('artists').reset_index(drop=True)
withGenre["artists"] = withGenre.artists.str.strip("\'")
withGenre["artists"] = withGenre.artists.str.strip("\"")
withGenre["artists"] = withGenre.artists.str.strip("\"")

withGenre["id_artists"] = withGenre.id_artists.str.strip("[]")
withGenre["id_artists"] = withGenre.id_artists.str.split(", ")
withGenre = withGenre.explode('id_artists').reset_index(drop=True)
withGenre["id_artists"] = withGenre.id_artists.str.strip("\'")
withGenre["id_artists"] = withGenre.id_artists.str.strip("\"")
withGenre["id_artists"] = withGenre.id_artists.str.strip("\"")

withGenre["duration_min"] = round(withGenre["duration_ms"]/1000/60, 2)

# %%
withGenre
# Out:
#                      id_artists                      id  \
# 0        5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 1        5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 2        3BiJGZsyX9sJchTqcSA7Su  08y9GfoqCWfOGsKdwojr5e
# 3        3BiJGZsyX9sJchTqcSA7Su  0BRXJHRNGQ3W4v9frnSfhu
# 4        4AxgXfD7ISvJSTObqm4aIE  0IA0Hju8CAgYfV1hwhidBH
# ...                         ...                     ...
# 1393259  4jGPdu95icCKVF31CcFKbS  45XJsGpFTyzbzeWK8VzR8S
# 1393260  5ebPSE9YI5aLeZ1Z2gkqjn  45XJsGpFTyzbzeWK8VzR8S
# 1393261  4jGPdu95icCKVF31CcFKbS  45XJsGpFTyzbzeWK8VzR8S
# 1393262  5ebPSE9YI5aLeZ1Z2gkqjn  45XJsGpFTyzbzeWK8VzR8S
# 1393263  0i4Qda0k4nf7jnNHmSNpYv  5Ocn6dZ3BJFPWh4ylwFXtn
#
#                                        name  popularity  duration_ms  \
# 0        Vivo para Quererte - Remasterizado           0       181640
# 1             El Prisionero - Remasterizado           0       176907
# 2                       Lady of the Evening           0       163080
# ...

# %%
artists_genre = pd.read_csv("../Resources/AprilUpdate/artists.csv")
artists_genre
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# ...

# %%
artists_genre.rename(columns = {
    "id": "id_artists",
    "name": "artists"
}, inplace = True)

artists_genre.drop(columns = ["popularity", "followers"], inplace=True)
artists_genre
# Out:
#                      id_artists                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2                     []
# 1        0DlhY15l3wsrnlfGio2bjU                     []
# 2        0DmRESX2JknGPQyO15yxg7                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E                     []
# ...                         ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB                     []
# 1104348  5m0Y4WSYyai2BU752lCASy                     []
#
#                                                 artists
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani
# 1                                           ปูนา ภาวิณี
# 2                                                 Sadaa
# 3                                             Tra'gruda
# ...

# %%
artists_genre["genres"] = artists_genre.genres.str.strip("[]")
artists_genre["genres"] = artists_genre.genres.str.split(", ")
artists_genre = artists_genre.explode('genres').reset_index(drop=True)
artists_genre["genres"] = artists_genre.genres.str.strip("\'")
artists_genre["genres"] = artists_genre.genres.str.strip("\"")
artists_genre["genres"] = artists_genre.genres.str.strip("\"")
artists_genre
# Out:
#                      id_artists             genres  \
# 0        0DheY5irMjBUeLybbCUEZ2
# 1        0DlhY15l3wsrnlfGio2bjU
# 2        0DmRESX2JknGPQyO15yxg7
# 3        0DmhnbHjm1qw6NCYPeZNgJ
# 4        0Dn11fWM7vHQ3rinvWEl4E
# ...                         ...                ...
# 1266571  6rJIG42vcWAf1UBdRFlQxB
# 1266572  1ljurfXKPlGncNdW3J8zJ8  deep acoustic pop
# 1266573  2vnT9YhKIvjVo9LnVjWmr2
# 1266574  3ID0E5XCvnJIYZEq043ZoB
# 1266575  5m0Y4WSYyai2BU752lCASy
#
#                                                 artists
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani
# 1                                           ปูนา ภาวิณี
# 2                                                 Sadaa
# 3                                             Tra'gruda
# 4                                Ioannis Panoutsopoulos
# ...                                                 ...
# 1266571                                      Cody Longo
# 1266572                                 Right the Stars
# ...

# %%
merged_artist_genres = pd.merge(withGenre, artists_genre, on = ["artists", "id_artists"], how = "inner")
merged_artist_genres.head()
# Out:
#                id_artists                      id  \
# 0  5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 1  5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 2  5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 3  5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 4  5LiOoJbxVSAMkBS2fUm3X2  0JV4iqw2lSKJaHBQZ0e5zK
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1  Vivo para Quererte - Remasterizado           0       181640         0
# 2       El Prisionero - Remasterizado           0       176907         0
# 3       El Prisionero - Remasterizado           0       176907         0
# 4       Martín Fierro - Remasterizado           0       181173         0
#
#            artists release_date  danceability  energy  ...  valence    tempo  \
# 0  Ignacio Corsini   1922-03-21         0.434  0.1770  ...    0.457  130.418
# ...

# %%
merged_artist_genres.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'loudness_scale', 'tempo_scale',
#        'duration_scale', 'popularity_scale', 'Assignments', 'duration_min',
#        'genres'],
#       dtype='object')

# %%
# merged_artist_genres.drop(columns = ["popularity_x", "popularity_y", "followers"], inplace=True)
# merged_artist_genres
# Out:
#                      id_artists                      id  \
# 0        5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 1        5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 2        5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 3        5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 4        5LiOoJbxVSAMkBS2fUm3X2  0JV4iqw2lSKJaHBQZ0e5zK
# ...                         ...                     ...
# 2246343  1dy5WNgIKQU6ezkpZs4y8z  0NuWgxEp51CutD2pJoF4OM
# 2246344  1dy5WNgIKQU6ezkpZs4y8z  0NuWgxEp51CutD2pJoF4OM
# 2246345  1dy5WNgIKQU6ezkpZs4y8z  0NuWgxEp51CutD2pJoF4OM
# 2246346  1dy5WNgIKQU6ezkpZs4y8z  0NuWgxEp51CutD2pJoF4OM
# 2246347  1dy5WNgIKQU6ezkpZs4y8z  0NuWgxEp51CutD2pJoF4OM
#
#                                        name  duration_ms  explicit  \
# 0        Vivo para Quererte - Remasterizado       181640         0
# 1        Vivo para Quererte - Remasterizado       181640         0
# 2             El Prisionero - Remasterizado       176907         0
# ...

# %%
merged_artist_genres.to_csv("../Resources/MLResources/merged_artists_w_genres.csv")

# %%
merged_artist = pd.read_csv("../Resources/MLResources/merged_artists_w_genres.csv")
merged_artist.columns
# Out:
# Index(['Unnamed: 0', 'id_artists', 'id', 'name', 'popularity', 'duration_ms',
#        'explicit', 'artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'loudness_scale',
#        'tempo_scale', 'duration_scale', 'popularity_scale', 'Assignments',
#        'duration_min', 'genres'],
#       dtype='object')

# %%
merged_artist["duration_min"].max()
# Out:
# 83.25

# %%
grouped_merged_artist = merged_artist.groupby("Assignments")
grouped_merged_artist.head()
# Out:
#        Unnamed: 0              id_artists                      id  \
# 0               0  5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 1               1  5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 2               2  5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 3               3  5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 4               4  5LiOoJbxVSAMkBS2fUm3X2  0JV4iqw2lSKJaHBQZ0e5zK
# 5               5  5LiOoJbxVSAMkBS2fUm3X2  0JV4iqw2lSKJaHBQZ0e5zK
# 6               6  5LiOoJbxVSAMkBS2fUm3X2  0l3BQsVJ7F76wlN5QhJzaP
# 7               7  5LiOoJbxVSAMkBS2fUm3X2  0l3BQsVJ7F76wlN5QhJzaP
# 8               8  5LiOoJbxVSAMkBS2fUm3X2  0xJCJ9XSNcdTIz0QKmhtEn
# 9               9  5LiOoJbxVSAMkBS2fUm3X2  0xJCJ9XSNcdTIz0QKmhtEn
# 10             10  5LiOoJbxVSAMkBS2fUm3X2  15BEv0mKGqHHxyDAcLJ7ei
# 14             14  5LiOoJbxVSAMkBS2fUm3X2  1KLKkACG16o5crQPiaF1Tz
# 15             15  5LiOoJbxVSAMkBS2fUm3X2  1KLKkACG16o5crQPiaF1Tz
# ...

# %%
grouped_artist_mean = grouped_merged_artist.mean()
grouped_artist_mean = grouped_artist_mean.drop(columns = "Unnamed: 0")
grouped_artist_mean
# Out:
#              popularity    duration_ms  explicit  danceability    energy  \
# Assignments
# 0             35.817916  257019.666737  0.076278      0.545359  0.473774
# 1             21.556628  234256.634166  0.004513      0.433738  0.241857
# 2             37.207885  230970.887099  0.093265      0.683281  0.723571
# 3             38.510728  249044.908541  0.112497      0.513813  0.796545
# 4             24.318524  216317.789032  0.019943      0.613181  0.507727
# 5             20.412516  191810.550241  0.024448      0.658399  0.396054
# 6             26.437425  257868.285318  0.034015      0.514822  0.754871
# 7             16.281190  325286.270240  0.001063      0.318502  0.157197
# 8             31.964231  270163.932470  0.060097      0.509021  0.715548
# 9             12.556307  207777.462524  0.000790      0.549743  0.373109
#
#                   key   loudness      mode  speechiness  acousticness  \
# Assignments
# ...

# %%
grouped_artist_mean.to_csv("../Resources/MLResources/grouped_artist_mean.csv")

# %%
grouped_artist_mean = pd.read_csv("../Resources/MLResources/grouped_artist_mean.csv")
grouped_artist_mean
# Out:
#    Assignments    Unnamed: 0  popularity    duration_ms  explicit  \
# 0            0  1.299237e+06   35.817916  257019.666737  0.076278
# 1            1  8.298135e+05   21.556628  234256.634166  0.004513
# 2            2  1.368393e+06   37.207885  230970.887099  0.093265
# 3            3  1.463117e+06   38.510728  249044.908541  0.112497
# 4            4  9.268209e+05   24.318524  216317.789032  0.019943
# 5            5  1.232073e+06   20.412516  191810.550241  0.024448
# 6            6  1.312608e+06   26.437425  257868.285318  0.034015
# 7            7  5.295773e+05   16.281190  325286.270240  0.001063
# 8            8  1.189486e+06   31.964231  270163.932470  0.060097
# 9            9  5.136546e+05   12.556307  207777.462524  0.000790
#
#    danceability    energy       key   loudness      mode  ...  \
# 0      0.545359  0.473774  5.130071 -10.037598  0.664051  ...
# 1      0.433738  0.241857  5.100359 -14.332690  0.707775  ...
# ...

# %%
grouped_artist_mean
# Out:
#    Assignments    Unnamed: 0  popularity    duration_ms  explicit  \
# 0            0  1.299237e+06   35.817916  257019.666737  0.076278
# 1            1  8.298135e+05   21.556628  234256.634166  0.004513
# 2            2  1.368393e+06   37.207885  230970.887099  0.093265
# 3            3  1.463117e+06   38.510728  249044.908541  0.112497
# 4            4  9.268209e+05   24.318524  216317.789032  0.019943
# 5            5  1.232073e+06   20.412516  191810.550241  0.024448
# 6            6  1.312608e+06   26.437425  257868.285318  0.034015
# 7            7  5.295773e+05   16.281190  325286.270240  0.001063
# 8            8  1.189486e+06   31.964231  270163.932470  0.060097
# 9            9  5.136546e+05   12.556307  207777.462524  0.000790
#
#    danceability    energy       key   loudness      mode  ...  \
# 0      0.545359  0.473774  5.130071 -10.037598  0.664051  ...
# 1      0.433738  0.241857  5.100359 -14.332690  0.707775  ...
# ...

# %%
grouped_artist_genres = merged_artist.groupby(["Assignments", "genres"])
# grouped_artist_genres.drop(columns = "Unnamed: 0", inplace = True)
grouped_artist_genre_count = grouped_artist_genres.count()
grouped_artist_genre_count.drop(columns = "Unnamed: 0", inplace = True)
grouped_artist_genre_count.to_csv("../Resources/MLResources/count_grouped_genre.csv")

# %%
pd.read_csv("../Resources/MLResources/cluster_genre_set.csv")
# Out:
#         Unnamed: 0                                         id_artists  \
# 0                0                         ['5LiOoJbxVSAMkBS2fUm3X2']
# 1                1                         ['5LiOoJbxVSAMkBS2fUm3X2']
# 2                2                         ['3BiJGZsyX9sJchTqcSA7Su']
# 3                3                         ['3BiJGZsyX9sJchTqcSA7Su']
# 4                4                         ['4AxgXfD7ISvJSTObqm4aIE']
# ...            ...                                                ...
# 549049      549049                         ['1QLBXKM5GCpyQQSVMNZqrZ']
# 549050      549050                         ['1dy5WNgIKQU6ezkpZs4y8z']
# 549051      549051                         ['37M5pPGs6V1fchFJSgCguX']
# 549052      549052  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...
# 549053      549053                         ['0i4Qda0k4nf7jnNHmSNpYv']
#
#                             id                                name  \
# ...

# %%
merged_artist = pd.read_csv("../Resources/MLResources/merged_artists_w_genres.csv")

# %%
merged_artist.columns
# Out:
# Index(['Unnamed: 0', 'id_artists', 'id', 'name', 'popularity', 'duration_ms',
#        'explicit', 'artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'loudness_scale',
#        'tempo_scale', 'duration_scale', 'popularity_scale', 'Assignments',
#        'duration_min', 'genres'],
#       dtype='object')

# %%
merged_artist.drop_duplicates(inplace = True)

# %%
merged_artist.head()
# Out:
#    Unnamed: 0              id_artists                      id  \
# 0           0  5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 1           1  5LiOoJbxVSAMkBS2fUm3X2  07A5yehtSnoedViJAZkNnc
# 2           2  5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 3           3  5LiOoJbxVSAMkBS2fUm3X2  08FmqUhxtyLTn6pAh6bk45
# 4           4  5LiOoJbxVSAMkBS2fUm3X2  0JV4iqw2lSKJaHBQZ0e5zK
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1  Vivo para Quererte - Remasterizado           0       181640         0
# 2       El Prisionero - Remasterizado           0       176907         0
# 3       El Prisionero - Remasterizado           0       176907         0
# 4       Martín Fierro - Remasterizado           0       181173         0
#
#            artists release_date  danceability  ...  valence    tempo  \
# 0  Ignacio Corsini   1922-03-21         0.434  ...    0.457  130.418
# ...

# %%
merged_artist[merged_artist["name"]=="24.11.94 - Wersja Akustyczna"]["popularity"]
# Out:
# 2236350    34
# Name: popularity, dtype: int64

# %%
sample100_merged = merged_artist

# %%
# REVISED NEW JSONs HERE
imploded_df_revised = (merged_artist.groupby(['id', 'name', 'artists', 'id_artists'])
      .agg({
#           'artists': lambda x: x.tolist(),
#             'id_artists':lambda x: x.tolist(),
            'genres': lambda x: x.tolist(),
            'Assignments':'first'
      })
#       .rename({'Case' : 'Avg_Cases','Delivery' : 'Avg_Delivery'},axis=1)
      .reset_index())
imploded_df_revised.tail()
# Out:
#                             id                    name              artists  \
# 689557  7zzoxJbgjme3366mOp5UnH  I Took A Pill In Ibiza          Mike Posner
# 689558  7zzqq4eJe4zKpYCHckNi1K     O Verme E A Estrela  Adriana Calcanhotto
# 689559  7zztLmdxNYrjTQ4XqUK8cp             Õhupiraadid           Vennaskond
# 689560  7zztk8Ecg9qDRLX3XNfSyq  Mitt hjärta i din hand         Jan Johansen
# 689561  7zzuPsjj9L3M7ikqGmjN0D         A Long Time Ago            Jim Croce
#
#                     id_artists  \
# 689557  2KsP6tYLJlTBvSUxnwlVWa
# 689558  72f733zGuCPEzCSLs9wOVi
# 689559  4SENxns1ygWdzNSNbBkaXZ
# 689560  4Nd6R1oljERR3D2893MpJf
# 689561  1R6Hx1tJ2VOUyodEpC12xM
#
#                                                    genres  Assignments
# 689557                          [dance pop, pop, pop rap]            1
# 689558                        [bossa nova, mpb, nova mpb]            1
# 689559                      [estonian pop, estonian rock]            3
# ...

# %%
# Revised version of JSON!!!!!!!!!!!
imploded_df_revised = imploded_df_revised.groupby("name").agg({'id': lambda x: x.tolist(), 'artists': lambda x: x.tolist(),'genres': lambda x: x.tolist(),'Assignments': lambda x: x.tolist()}).reset_index()
imploded_df_revised
# Out:
#                                                      name  \
# 0                                   Artista "" Por un Mes
# 1                    El Profesor Tachuela "" (Tacuarembó)
# 2                                                       !
# 3                          ! (The Song Formerly Known As)
# 4                                          !!De Repente!!
# ...                                                   ...
# 408948                                     행복 (Happiness)
# 408949                            행복했던 날들이었다 days gone by
# 408950  헤어지지 못하는 여자, 떠나가지 못하는 남자 Can't Breakup Girl, C...
# 408951                                 헤픈엔딩 Happen Ending
# 408952                화려하지 않은 고백 Confession Is Not Flashy
#
#                                                       id  \
# 0       [1EpAkslThEkO4VwEENOt4m, 1EpAkslThEkO4VwEENOt4m]
# 1       [5pDcRriCV5OUYDRQFr977V, 5pDcRriCV5OUYDRQFr977V]
# 2       [1A05ibu1DXGIt0F62NG7xU, 1A05ibu1DXGIt0F62NG7xU]
# ...

# %%
imploded_df_revised.to_json("../Resources/MLResources/revised_full_Imploded.json", orient = "records")

# %%
imploded_to_json_Ass = (merged_artist.groupby(['id', 'name', 'artists', 'id_artists'])
      .agg({
#           'artists': lambda x: x.tolist(),
#             'id_artists':lambda x: x.tolist(),
            'genres': lambda x: x.tolist(),
            'Assignments':'first'
      })
#       .rename({'Case' : 'Avg_Cases','Delivery' : 'Avg_Delivery'},axis=1)
      .reset_index())

# %%
# Assignments JSON
imploded_to_json_Ass = imploded_df.groupby("Assignments").agg({'name': lambda x: x.tolist(), 'artists': lambda x: x.tolist(),'genres': lambda x: x.tolist(), 'id': lambda x: x.tolist()}).reset_index()
imploded_to_json_Ass
# Out:
#    Assignments                                               name  \
# 0            0  [24.11.94 - Wersja Akustyczna, Tenebre, Tenebr...
# 1            1  [Podrás, Undrastrákurinn Óli, My Shining Hour,...
# 2            2  [Adam et Ève, Teeje Week, Es un Secreto, Es un...
# 3            3  [Will Anything Happen, Paris sous les bombes, ...
# 4            4  [El Licor de Tu Boquita, Me Quieres Perjudicar...
# 5            5  [Balla Trazan Apansson / Vegetarianvisan, 008 ...
# 6            6  [Doubts Even Here - 2015 Remaster, Petrol - 20...
# 7            7  [Mere Hamsafar, Symphony in B-Flat Major, Op. ...
# 8            8  [(I Can't Get No) Satisfaction - Live in Europ...
# 9            9  [Uth Soye Huye Husn, Lute Suite in E Minor, BW...
#
#                                              artists  \
# 0  [Golden Life, Sercho, Ultimo, Texas, Heart, Ba...
# 1  [Tamara Castro, Þrjú á palli ásamt Sólskinskór...
# 2  [Kaïn, Jordan Sandhu, Plan B, Tego, Los Invaso...
# ...

# %%
imploded_to_json_Ass.to_json("../Resources/MLResources/Assignments_full_Imploded.json", orient = "records")

# %%
imploded_to_json.to_json("../Resources/MLResources/full_Imploded.json", orient = "records")

# %%
sample = merged_artist.head(100)
sample.groupby('name').head()
sample.dtypes
# Out:
# Unnamed: 0            int64
# id_artists           object
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# loudness_scale      float64
# tempo_scale         float64
# duration_scale      float64
# popularity_scale    float64
# Assignments           int64
# duration_min        float64
# genres               object
# dtype: object

# %%
j = (sample.groupby(['name', 'Assignments'])
             .apply(lambda x: x['artists, id_artists'].to_dict('r'))
#                     lambda x: x[['genres']].to_dict('r')
#                     lambda x: x[['Assignments']].to_dict('r')
#              .apply(lambda x: x[['genres']].to_dict('r'))
#              .apply(lambda x: x['Assignments'].to_dict('r'))
             .reset_index()
#              .rename(columns={0:'Artist_Info', 1:'Assignments'})
             .rename(columns={0:'Artist_Info'})
#              .rename(columns={0:'Genre'})
             .to_json("../Resources/MLResources/sample.json", orient='records'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-104-edee705cdc49> in <lambda>(x)
#       1 j = (sample.groupby(['name'])
# ...

# %%
j = (df.groupby(['name','artists','id_artists','genre','Assignments'], as_index=False)
             .apply(lambda x: x[['timestamp','tide']].to_dict('r'))
             .reset_index()
             .rename(columns={0:'Tide-Data'})
             .to_json(orient='records'))

# %%
j = (sample.groupby([['name', 'artists','id_artists']], as_index=False)
#              .apply(lambda x: x[['artists','id_artists']].to_dict('r'))
#              .reset_index()
#              .rename(columns={0:'song-info'})
             .to_json(orient='records'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-7fab12387b9b> in <module>
# ----> 1 j = (sample.groupby([['name', 'artists','id_artists']], as_index=False)
#       2 #              .apply(lambda x: x[['artists','id_artists']].to_dict('r'))
#       3 #              .reset_index()
#       4 #              .rename(columns={0:'song-info'})
#       5              .to_json(orient='records'))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ...

# %%
sample.set_index('name')['value'].to_dict()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-4a416b1d2f89> in <module>
# ...

# %%
imploded_sample = imploded_df.head(100)

# %%
imploded_sample.to_json("../Resources/MLResources/imploded_sample.json", orient='records')

# %%
"Artists_Info" =
