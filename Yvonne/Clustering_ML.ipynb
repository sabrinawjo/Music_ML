# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/AprilUpdate/tracks_genrePotential.csv")
df.head()
# Out:
#                    id_artists                      id  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2  ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4  ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1       El Prisionero - Remasterizado           0       176907         0
# 2                 Lady of the Evening           0       163080         0
# 3                           Ave Maria           0       178933         0
# 4                             La Java           0       161427         0
#
#                artists release_date  danceability  energy  key  loudness  \
# 0  ['Ignacio Corsini']   1922-03-21         0.434  0.1770    1   -21.180
# ...

# %%
df = df[df["loudness"]<=0]
df.head()
# Out:
#                    id_artists                      id  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2  ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4  ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1       El Prisionero - Remasterizado           0       176907         0
# 2                 Lady of the Evening           0       163080         0
# 3                           Ave Maria           0       178933         0
# 4                             La Java           0       161427         0
#
#                artists release_date  danceability  energy  key  loudness  \
# 0  ['Ignacio Corsini']   1922-03-21         0.434  0.1770    1   -21.180
# ...

# %%
df["loudness_scale"] = 1-(df["loudness"]/df["loudness"].min())
df["tempo_scale"] = df["tempo"]/df["tempo"].max()
df["duration_scale"] = df["duration_ms"]/df["duration_ms"].max()
df["popularity_scale"] = df["popularity"]/df["popularity"].max()
df.head()
# Out:
#                    id_artists                      id  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2  ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4  ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1       El Prisionero - Remasterizado           0       176907         0
# 2                 Lady of the Evening           0       163080         0
# 3                           Ave Maria           0       178933         0
# 4                             La Java           0       161427         0
#
#                artists release_date  danceability  energy  ...  acousticness  \
# 0  ['Ignacio Corsini']   1922-03-21         0.434  0.1770  ...         0.994
# ...

# %%
df.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'loudness_scale', 'tempo_scale',
#        'duration_scale', 'popularity_scale'],
#       dtype='object')

# %%
df.to_csv("../Resources/clean_clustering_ml_data.csv", index=False)

# %%
clean = pd.read_csv("../Resources/clean_clustering_ml_data.csv")
clean.head()
# Out:
#                    id_artists                      id  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2  ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4  ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1       El Prisionero - Remasterizado           0       176907         0
# 2                 Lady of the Evening           0       163080         0
# 3                           Ave Maria           0       178933         0
# 4                             La Java           0       161427         0
#
#                artists release_date  danceability  energy  ...  acousticness  \
# 0  ['Ignacio Corsini']   1922-03-21         0.434  0.1770  ...         0.994
# ...

# %%
sample_df = df.head(100)
sample_df.to_csv("sample100_data.csv", index=False)

# %%
new = pd.read_csv("sample100_data.csv")
new
# Out:
#                     id_artists                      id  \
# 0   ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1   ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2   ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3   ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4   ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
# ..                         ...                     ...
# 95  ['19eLuQmk9aCobbVDHc6eek']  5WlMyDvyQedom0kQ3MCTow
# 96  ['6RuQvIr0t0otZHnAxXTGkm']  1UdqHVRFYMZKU2Q7xkLtYc
# 97  ['5ESobCkc6JI4tIMxQttqeg']  0F5F4GWA0Tz1ebZlLar2wG
# 98  ['6RuQvIr0t0otZHnAxXTGkm']  0Vl2DO5U6FjgBpzCtBN3OA
# 99  ['5ESobCkc6JI4tIMxQttqeg']  1h0wyCVd12PDSd6CLoGaVL
#
#                                   name  popularity  duration_ms  explicit  \
# 0   Vivo para Quererte - Remasterizado           0       181640         0
# 1        El Prisionero - Remasterizado           0       176907         0
# 2                  Lady of the Evening           0       163080         0
# ...

# %%
popular_cluster = pd.read_csv("sample_cluster_test_w_popularity_dataset.csv")
popular_cluster
# Out:
#                     id_artists                      id  \
# 0   ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1   ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2   ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3   ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4   ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
# ..                         ...                     ...
# 95  ['19eLuQmk9aCobbVDHc6eek']  5WlMyDvyQedom0kQ3MCTow
# 96  ['6RuQvIr0t0otZHnAxXTGkm']  1UdqHVRFYMZKU2Q7xkLtYc
# 97  ['5ESobCkc6JI4tIMxQttqeg']  0F5F4GWA0Tz1ebZlLar2wG
# 98  ['6RuQvIr0t0otZHnAxXTGkm']  0Vl2DO5U6FjgBpzCtBN3OA
# 99  ['5ESobCkc6JI4tIMxQttqeg']  1h0wyCVd12PDSd6CLoGaVL
#
#                                   name  popularity  duration_ms  explicit  \
# 0   Vivo para Quererte - Remasterizado           0       181640         0
# 1        El Prisionero - Remasterizado           0       176907         0
# 2                  Lady of the Evening           0       163080         0
# ...

# %%
no_popular = pd.read_csv("sample_cluster_test_no_popularity_dataset.csv")
no_popular.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'loudness_scale', 'tempo_scale',
#        'duration_scale', 'popularity_scale', 'Assignments',
#        'DistancesToClusterCenter no.0', 'DistancesToClusterCenter no.1',
#        'DistancesToClusterCenter no.2', 'DistancesToClusterCenter no.3',
#        'DistancesToClusterCenter no.4', 'DistancesToClusterCenter no.5',
#        'DistancesToClusterCenter no.6', 'DistancesToClusterCenter no.7',
#        'DistancesToClusterCenter no.8', 'DistancesToClusterCenter no.9',
#        'DistancesToClusterCenter no.10', 'DistancesToClusterCenter no.11',
#        'DistancesToClusterCenter no.12', 'DistancesToClusterCenter no.13',
#        'DistancesToClusterCenter no.14', 'DistancesToClusterCenter no.15',
# ...

# %%
for column in no_popular:
    if "DistancesToClusterCenter" in column:
        no_popular.drop(column, axis=1, inplace=True)
clean_no_popular = no_popular
clean_no_popular.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'loudness_scale', 'tempo_scale',
#        'duration_scale', 'popularity_scale', 'Assignments'],
#       dtype='object')

# %%
grouped_clean_no_popular = clean_no_popular.groupby("Assignments")
grouped_clean_no_popular.describe()
# Out:
#             popularity                                                        \
#                  count       mean        std   min    25%   50%    75%   max
# Assignments
# 0                  7.0  14.857143   8.513295   0.0  11.00  14.0  22.50  23.0
# 1                 13.0   0.000000   0.000000   0.0   0.00   0.0   0.00   0.0
# 2                  1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# 3                  3.0   0.000000   0.000000   0.0   0.00   0.0   0.00   0.0
# 4                  2.0  35.500000   7.778175  30.0  32.75  35.5  38.25  41.0
# 5                  5.0  11.600000  17.111400   0.0   0.00   0.0  20.00  38.0
# 6                  4.0   5.750000  11.500000   0.0   0.00   0.0   5.75  23.0
# 7                  2.0   0.000000   0.000000   0.0   0.00   0.0   0.00   0.0
# 8                  9.0   0.000000   0.000000   0.0   0.00   0.0   0.00   0.0
# 9                 10.0   0.400000   1.264911   0.0   0.00   0.0   0.00   4.0
# ...

# %%
grouped_clean_no_popular[grouped_clean_no_popular[]]

# %%
song = input("Input song name here    ")
count = int(input("How many songs do you want recommended?    "))

if song != "":
    referenced_song = clean_no_popular[clean_no_popular["name"]==song]
    assignment = int(referenced_song["Assignments"])
    song_assignments = clean_no_popular[clean_no_popular["Assignments"]==assignment]
    print("")
    print(song_assignments.name[0:count])
# Out:
# Input song name here    Muggles
# How many songs do you want recommended?    3
#
# 22                                  En Douce
# 84                           St. Louis Blues
# 85    St. Louis Blues (with Louis Armstrong)
# Name: name, dtype: object

# %%
song = "Muggles"
referenced_song = clean_no_popular[clean_no_popular["name"]==song]
assignment = int(referenced_song["Assignments"])
# assignment
song_assignments = clean_no_popular[clean_no_popular["Assignments"]==assignment]
song_assignments.name
# song_assignments.name.head(10)
# Out:
# 22                                  En Douce
# 84                           St. Louis Blues
# 85    St. Louis Blues (with Louis Armstrong)
# 86                           Backwater Blues
# 93                                   Muggles
# 96                      Pickin' On Your Baby
# 97                          Work House Blues
# Name: name, dtype: object

# %%
song = "Muggles"
referenced_song = clean_no_popular[clean_no_popular["name"]==song]
assignment = int(referenced_song["Assignments"])
assignment
# Out:
# 0

# %%
song = "Preachin' the Blues"
if song in clean_no_popular["name"]:
    print("True")
else:
    print("False")
# Out:
# False

# %%
song = "Preachin' the Blues"
"Ave Maria" in clean_no_popular["name"]
# Out:
# False

# %%
song = "Preachin' the Blues"
clean_no_popular[clean_no_popular["name"]==song]
# Out:
#                     id_artists                      id                 name  \
# 99  ['5ESobCkc6JI4tIMxQttqeg']  1h0wyCVd12PDSd6CLoGaVL  Preachin' the Blues
#
#     popularity  duration_ms  explicit           artists release_date  \
# 99          11       171027         0  ['Bessie Smith']         1923
#
#     danceability  energy  ...  instrumentalness  liveness  valence    tempo  \
# 99         0.703   0.185  ...           0.00209      0.22    0.491  104.916
#
#     time_signature  loudness_scale  tempo_scale  duration_scale  \
# 99               4         0.86125     0.430854        0.031651
#
#     popularity_scale  Assignments
# 99              0.11           11
#
# [1 rows x 25 columns]

# %%
clean_no_popular[clean_no_popular['name'].str.contains('Ave Maria')]
# Out:
#                    id_artists                      id       name  popularity  \
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu  Ave Maria           0
#
#    duration_ms  explicit          artists release_date  danceability  energy  \
# 3       178933         0  ['Dick Haymes']         1922         0.227   0.261
#
#    ...  instrumentalness  liveness  valence    tempo  time_signature  \
# 3  ...             0.247    0.0977   0.0539  118.891               4
#
#    loudness_scale  tempo_scale  duration_scale  popularity_scale  Assignments
# 3        0.794283     0.488245        0.033114               0.0           16
#
# [1 rows x 25 columns]
