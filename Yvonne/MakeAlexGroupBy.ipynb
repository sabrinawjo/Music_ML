# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/whole_cluster_dataset.csv")
df.head()
# Out:
#                    id_artists                      id  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']  07A5yehtSnoedViJAZkNnc
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']  08FmqUhxtyLTn6pAh6bk45
# 2  ['3BiJGZsyX9sJchTqcSA7Su']  08y9GfoqCWfOGsKdwojr5e
# 3  ['3BiJGZsyX9sJchTqcSA7Su']  0BRXJHRNGQ3W4v9frnSfhu
# 4  ['4AxgXfD7ISvJSTObqm4aIE']  0IA0Hju8CAgYfV1hwhidBH
#
#                                  name  popularity  duration_ms  explicit  \
# 0  Vivo para Quererte - Remasterizado           0       181640         0
# 1       El Prisionero - Remasterizado           0       176907         0
# 2                 Lady of the Evening           0       163080         0
# 3                           Ave Maria           0       178933         0
# 4                             La Java           0       161427         0
#
#                artists release_date  danceability  energy  ...  \
# 0  ['Ignacio Corsini']   1922-03-21         0.434  0.1770  ...
# 1  ['Ignacio Corsini']   1922-03-21         0.321  0.0946  ...
# ...

# %%
for column in df:
    if "DistancesToClusterCenter" in column:
        df.drop(column, axis=1, inplace=True)
clean_df = df
clean_df
# Out:
#                                                id_artists  \
# 0                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 1                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 2                              ['3BiJGZsyX9sJchTqcSA7Su']
# 3                              ['3BiJGZsyX9sJchTqcSA7Su']
# 4                              ['4AxgXfD7ISvJSTObqm4aIE']
# ...                                                   ...
# 549049                         ['1QLBXKM5GCpyQQSVMNZqrZ']
# 549050                         ['1dy5WNgIKQU6ezkpZs4y8z']
# 549051                         ['37M5pPGs6V1fchFJSgCguX']
# 549052  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...
# 549053                         ['0i4Qda0k4nf7jnNHmSNpYv']
#
#                             id                                name  \
# 0       07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 1       08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# ...

# %%
clean_df.to_csv("../Resources/clean_whole_cluster_dataset.csv", index = False)

# %%
clean_df = pd.read_csv("../Resources/clean_whole_cluster_dataset.csv")
clean_df
# Out:
#                                                id_artists  \
# 0                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 1                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 2                              ['3BiJGZsyX9sJchTqcSA7Su']
# 3                              ['3BiJGZsyX9sJchTqcSA7Su']
# 4                              ['4AxgXfD7ISvJSTObqm4aIE']
# ...                                                   ...
# 549049                         ['1QLBXKM5GCpyQQSVMNZqrZ']
# 549050                         ['1dy5WNgIKQU6ezkpZs4y8z']
# 549051                         ['37M5pPGs6V1fchFJSgCguX']
# 549052  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...
# 549053                         ['0i4Qda0k4nf7jnNHmSNpYv']
#
#                             id                                name  \
# 0       07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 1       08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# ...

# %%
clean_df.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'loudness_scale', 'tempo_scale',
#        'duration_scale', 'popularity_scale', 'Assignments'],
#       dtype='object')

# %%
grouped_df = clean_df.groupby("Assignments")
grouped_mean = grouped_df.mean()
grouped_mean.head()
# Out:
#              popularity    duration_ms  explicit  danceability    energy  \
# Assignments
# 0             33.233288  223689.079068  0.051389      0.713702  0.759117
# 1             24.760274  129119.907638  0.016189      0.682281  0.450687
# 2             15.544011  236961.648501  0.000711      0.458474  0.131823
# 3             32.780157  274026.229511  0.022257      0.417969  0.467561
# 4             20.594196  204466.903353  0.004333      0.536922  0.192034
#
#                   key   loudness      mode  speechiness  acousticness  \
# Assignments
# 0            5.352308  -6.833558  0.633957     0.075193      0.407441
# 1            5.199253 -13.297556  0.647364     0.876544      0.733695
# 2            4.872053 -20.302505  0.677526     0.052334      0.961489
# 3            5.053274  -9.949132  0.676595     0.040523      0.156564
# 4            5.110523 -14.619021  0.709490     0.055362      0.891252
#
# ...

# %%
grouped_mean.to_csv("../Resources/grouped_whole_cluster.csv")
