# %%
import pandas as pd

# %%
path = "~/Desktop/merged_artists_w_genres.csv"
data = pd.read_csv(path)

# %%
data.drop(columns='Unnamed: 0', inplace = True)

# %%
data_trx_art_assign = data[['id_artists','id','name','artists','Assignments','genres']]

# %%
data_trx_art_assign.to_csv('data_trx_art_assign.csv', index=False)

# %%
ave_maria = data_trx_art_assign[data_trx_art_assign['name']=='Ave Maria']

# %%
ave_maria
# Out:
#                      id_artists                      id       name  \
# 1125     3BiJGZsyX9sJchTqcSA7Su  0BRXJHRNGQ3W4v9frnSfhu  Ave Maria
# 1126     3BiJGZsyX9sJchTqcSA7Su  0BRXJHRNGQ3W4v9frnSfhu  Ave Maria
# 1127     3BiJGZsyX9sJchTqcSA7Su  0BRXJHRNGQ3W4v9frnSfhu  Ave Maria
# 1128     3BiJGZsyX9sJchTqcSA7Su  0BRXJHRNGQ3W4v9frnSfhu  Ave Maria
# 1129     3BiJGZsyX9sJchTqcSA7Su  0BRXJHRNGQ3W4v9frnSfhu  Ave Maria
# ...                         ...                     ...        ...
# 2196080  1uCNpbfORkCIOyn6gYMRtR  7HT0dcnizrJrVjMJMgiLkF  Ave Maria
# 2200012  4gQXRvD8CKSLIJR09WhrRK  2kfeWxnFx8aur6rCMiEt8P  Ave Maria
# 2200013  3fGtLlq8qrB9tmFOjBBe5M  2kfeWxnFx8aur6rCMiEt8P  Ave Maria
# 2200014  3fGtLlq8qrB9tmFOjBBe5M  2kfeWxnFx8aur6rCMiEt8P  Ave Maria
# 2214468  5vbrczoZLVdjnPuXS7pIt2  5RpkqG5pG6F3twW89jZrVN  Ave Maria
#
#                   artists  Assignments           genres
# 1125          Dick Haymes            1  adult standards
# ...
