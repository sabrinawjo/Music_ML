# %%
import pandas as pd

tracks = "~/Downloads/aprilDownload/tracks.csv"
artists = "../Resources/AprilUpdate/artists.csv"
data_by_genres_o = "../Resources/Archive/data_by_genres_o.csv"
data_o = "../Resources/Archive/data_o.csv"

tracks_df = pd.read_csv(tracks)
artists_df = pd.read_csv(artists)
data_o_df = pd.read_csv(data_o)
data_by_genres_df = pd.read_csv(data_by_genres_o)

# tracks_df.head(3)
artists_df.head()
# data_by_genres_df
# data_o_df
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
artists_genres_df = artists_df.loc[artists_df['genres']!="[]"]
artists_noGenre_df = artists_df.loc[artists_df['genres']=='[]']

# %%
artists_genres_df.head()
# Out:
#                          id  followers                      genres  \
# 45   0VLMVnVbJyJ4oyZs2L3Yl2       71.0          ['carnaval cadiz']
# 46   0dt23bs4w8zx154C5xdVyl       63.0          ['carnaval cadiz']
# 47   0pGhoB99qpEJEsBQxgaskQ       64.0          ['carnaval cadiz']
# 48   3HDrX2OtSuXLW5dLR85uN3       53.0          ['carnaval cadiz']
# 136  22mLrN5fkppmuUPsHx6i2G       59.0  ['classical harp', 'harp']
#
#                              name  popularity
# 45   Las Viudas De Los Bisabuelos           6
# 46              Los De Capuchinos           5
# 47             Los “Pofesionales”           7
# 48      Los Que No Paran De Rajar           6
# 136                   Vera Dulova           3

# %%
artists_noGenre_df['id_artists']="[\'"+artists_noGenre_df['id']+"\']"
artists_noGenre_df['NoGenreFlag']=int(1)
artists_noGenre_df = artists_noGenre_df[['id_artists','NoGenreFlag']]
artists_noGenre_df.head(3)
# Out:
# <ipython-input-56-987c2d2dd9f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artists_noGenre_df['id_artists']="[\'"+artists_noGenre_df['id']+"\']"
# <ipython-input-56-987c2d2dd9f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artists_noGenre_df['NoGenreFlag']=int(1)
#                    id_artists  NoGenreFlag
# 0  ['0DheY5irMjBUeLybbCUEZ2']            1
# 1  ['0DlhY15l3wsrnlfGio2bjU']            1
# 2  ['0DmRESX2JknGPQyO15yxg7']            1

# %%
tracks_genreflags_df = artists_noGenre_df.merge(tracks_df, how='right', on='id_artists')
tracks_genrePotential = tracks_genreflags_df.loc[tracks_genreflags_df['NoGenreFlag']!=1]
tracks_genrePotential = tracks_genrePotential.drop(columns='NoGenreFlag')

tracks_genrePotential.to_csv('../Resources/AprilUpdate/tracks_genrePotential.csv', index=False)
# Out:
#                                                id_artists  \
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']
# 5                              ['3BiJGZsyX9sJchTqcSA7Su']
# 7                              ['4AxgXfD7ISvJSTObqm4aIE']
# ...                                                   ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']
# 586669                         ['37M5pPGs6V1fchFJSgCguX']
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']
#
#                             id                                name  \
# 2       07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                 Lady of the Evening
# 5       0BRXJHRNGQ3W4v9frnSfhu                           Ave Maria
# 7       0IA0Hju8CAgYfV1hwhidBH                             La Java
# ...                        ...                                 ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                 云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                               blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2           What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                     A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                    Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# 5                0       178933         0                  ['Dick Haymes']
# 7                0       161427         0                  ['Mistinguett']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#        release_date  danceability  energy  key  loudness  mode  speechiness  \
# 2        1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3        1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4              1922         0.402  0.1580    3   -16.900     0       0.0390
# 5              1922         0.227  0.2610    5   -12.343     1       0.0382
# 7              1922         0.563  0.1840    4   -13.757     1       0.0512
# ...             ...           ...     ...  ...       ...   ...          ...
# 586667   2020-09-26         0.560  0.5180    0    -7.471     0       0.0292
# 586668   2020-10-21         0.765  0.6630    0    -5.223     1       0.0652
# 586669   2020-09-02         0.535  0.3140    7   -12.823     0       0.0408
# 586670   2021-03-05         0.696  0.6150   10    -6.212     1       0.0345
# 586671   2015-07-01         0.686  0.7230    6    -7.067     1       0.0363
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 2              0.994          0.021800    0.2120   0.4570  130.418
# 3              0.995          0.918000    0.1040   0.3970  169.980
# 4              0.989          0.130000    0.3110   0.1960  103.220
# 5              0.994          0.247000    0.0977   0.0539  118.891
# 7              0.993          0.000016    0.3250   0.6540  133.088
# ...              ...               ...       ...      ...      ...
# 586667         0.785          0.000000    0.0648   0.2110  131.896
# 586668         0.141          0.000297    0.0924   0.6860  150.091
# 586669         0.895          0.000150    0.0874   0.0663  145.095
# 586670         0.206          0.000003    0.3050   0.4380   90.029
# 586671         0.105          0.000000    0.2640   0.9750  112.204
#
#         time_signature
# 2                    5
# 3                    3
# 4                    4
# 5                    4
# 7                    3
# ...                ...
# 586667               4
# 586668               4
# 586669               4
# 586670               4
# 586671               4
#
# [549251 rows x 20 columns]

# %%
data_by_genres_df
# Out:
#       mode                  genres  acousticness  danceability   duration_ms  \
# 0        1  21st century classical      0.979333      0.162883  1.602977e+05
# 1        1                   432hz      0.494780      0.299333  1.048887e+06
# 2        1                   8-bit      0.762000      0.712000  1.151770e+05
# 3        1                      []      0.651417      0.529093  2.328809e+05
# 4        1              a cappella      0.676557      0.538961  1.906285e+05
# ...    ...                     ...           ...           ...           ...
# 2968     1                    zolo      0.222625      0.547082  2.580991e+05
# 2969     0                 zouglou      0.161000      0.863000  2.063200e+05
# 2970     1                    zouk      0.263261      0.748889  3.060728e+05
# 2971     0            zurich indie      0.993000      0.705667  1.984173e+05
# 2972     1                  zydeco      0.421038      0.629409  1.716717e+05
#
#         energy  instrumentalness  liveness   loudness  speechiness  \
# 0     0.071317          0.606834  0.361600 -31.514333     0.040567
# 1     0.450678          0.477762  0.131000 -16.854000     0.076817
# 2     0.818000          0.876000  0.126000  -9.180000     0.047000
# 3     0.419146          0.205309  0.218696 -12.288965     0.107872
# 4     0.316434          0.003003  0.172254 -12.479387     0.082851
# ...        ...               ...       ...        ...          ...
# 2968  0.610240          0.143872  0.204206 -11.295878     0.061088
# 2969  0.909000          0.000000  0.108000  -5.985000     0.081300
# 2970  0.622444          0.257227  0.089678 -10.289222     0.038778
# 2971  0.172667          0.468633  0.179667 -11.453333     0.348667
# 2972  0.609369          0.019248  0.255877  -9.854825     0.050491
#
#            tempo   valence  popularity  key
# 0      75.336500  0.103783   27.833333    6
# 1     120.285667  0.221750   52.500000    5
# 2     133.444000  0.975000   48.000000    7
# 3     112.857352  0.513604   20.859882    7
# 4     112.110362  0.448249   45.820071    7
# ...          ...       ...         ...  ...
# 2968  125.494919  0.596155   33.778943    9
# 2969  119.038000  0.845000   58.000000    7
# 2970  101.965222  0.824111   46.666667    5
# 2971   91.278000  0.739000    0.000000    7
# 2972  126.366087  0.808544   30.261905    7
#
# [2973 rows x 14 columns]

# %%
genres_popular = data_by_genres_df[['genres','popularity']]
gp_sorted = genres_popular.sort_values(by=["popularity"], ascending = False)
gp_sorted
# Out:
#                       genres  popularity
# 237                 basshall   80.666667
# 2778             turkish edm   80.000000
# 2533     south african house   80.000000
# 2755         trap venezolano   80.000000
# 46           alberta hip hop   78.500000
# ...                      ...         ...
# 2888     vintage spanish pop    0.000000
# 828   deep progressive house    0.000000
# 1428            israeli folk    0.000000
# 2681               tajik pop    0.000000
# 1723                medieval    0.000000
#
# [2973 rows x 2 columns]

# %%
gp_sorted.to_csv('genres_popularity.csv', index=False)

# %%
pop_df = gp_sorted.loc[gp_sorted['genres']=="pop"]
country_df = gp_sorted[gp_sorted['genres'].str.contains('country')]
rock_df = gp_sorted[gp_sorted['genres'].str.contains('rock')]

# %%
rock_df
# Out:
#                      genres  popularity
# 2346            rock chapin        74.0
# 1505    japanese indie rock        72.0
# 1170        german pop rock        70.4
# 2564    spanish modern rock        65.0
# 1376          indie rockism        64.3
# ...                     ...         ...
# 2714         thai folk rock         1.0
# 140   atmospheric post-rock         0.0
# 2272     punk rock italiano         0.0
# 1329         hungarian rock         0.0
# 840         deep space rock         0.0
#
# [213 rows x 2 columns]

# %% [markdown]
# ### Artist Genres

# %%
artists_genres_df = artists_df.loc[artists_df['genres']!="[]"]
# artists_genres_df

# %%
# Turn the strings in the genres column into lists
# ['social meadia pop', 'teen pop']
artists_genres_df['genres'] = artists_genres_df.genres.apply(lambda x: x.replace("\"", "\'")) # ', '
artists_genres_df['genres'] = artists_genres_df.genres.apply(lambda x: x[2:-2].split("\', \'")) # ', '
# artists_genres_df['genres'] = artists_genres_df.genres.apply(lambda x: (x[bob].strip("\'") for bob in x))
# Out:
# <ipython-input-150-2de005c8ef90>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artists_genres_df['genres'] = artists_genres_df.genres.apply(lambda x: x.replace("\"", "\'")) # ', '
# <ipython-input-150-2de005c8ef90>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artists_genres_df['genres'] = artists_genres_df.genres.apply(lambda x: x[2:-2].split("\', \'")) # ', '

# %%
artists_genres_df
# Out:
#                              id  followers                        genres  \
# 45       0VLMVnVbJyJ4oyZs2L3Yl2       71.0              [carnaval cadiz]
# 46       0dt23bs4w8zx154C5xdVyl       63.0              [carnaval cadiz]
# 47       0pGhoB99qpEJEsBQxgaskQ       64.0              [carnaval cadiz]
# 48       3HDrX2OtSuXLW5dLR85uN3       53.0              [carnaval cadiz]
# 136      22mLrN5fkppmuUPsHx6i2G       59.0        [classical harp, harp]
# ...                         ...        ...                           ...
# 1104328  1q9C5XlekzXbRLIuLCDTre    90087.0  [social media pop, teen pop]
# 1104331  4fh2BIKYPFvXFsQLhaeVJp      309.0                    [la indie]
# 1104334  7akMsd2vb4xowNTehv3gsY      774.0               [indie rockism]
# 1104336  35m7AJrUCtHYHyIUhCzmgi      205.0               [indie rockism]
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0           [deep acoustic pop]
#
#                                  name  popularity
# 45       Las Viudas De Los Bisabuelos           6
# 46                  Los De Capuchinos           5
# 47                 Los “Pofesionales”           7
# 48          Los Que No Paran De Rajar           6
# 136                       Vera Dulova           3
# ...                               ...         ...
# 1104328                  Brent Rivera          33
# 1104331                   Lone Kodiak          20
# 1104334                    The Str!ke           0
# 1104336                 Hunter Fraser           6
# 1104345               Right the Stars          18
#
# [298616 rows x 5 columns]

# %%
artists_genres_df['genre_count'] = artists_genres_df['genres'].apply(lambda x: len(x))
# Out:
# <ipython-input-153-4f9fcaea6e87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artists_genres_df['genre_count'] = artists_genres_df['genres'].apply(lambda x: len(x))

# %%
single_genre_artists_df = artists_genres_df.loc[artists_genres_df['genre_count']==1]
single_genre_artists_df['genres'] = single_genre_artists_df.genres.apply(lambda x: x[0])
single_genre_artists_df.to_csv("../Resources/AprilUpdate/single_genre_artists.csv")
# single_genres = single_genre_artists_df['genres']
# single_genre_counts = single_genres.value_counts()
# Out:
# <ipython-input-156-7b4a4b93c876>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_genre_artists_df['genres'] = single_genre_artists_df.genres.apply(lambda x: x[0])

# %%
single_genre_counts.to_csv('single_genre_counts.csv')

# %%
quote_issues = single_genre_artists_df[single_genre_artists_df['genres'].str.contains("\'")]
childrens = quote_issues[quote_issues['genres'].str.contains("children\'s")]
childrens
# quotes_commas = quote_issues[quote_issues['genres'].str.contains(",")]
# quotes_commas['genres'].value_counts().head(50)
# Out:
#                              id  followers                       genres  \
# 144      4sTTEheJxmjwv9TmrHOaPz      288.0             children's story
# 1501     0i3dJ6fbFXG9zEPAuAloZG     1134.0  australian children's music
# 1525     057riJyTUFQRYI5mAjpVTw     1068.0  australian children's music
# 1548     4I0BixMk7zPyKimeO3HrTa     1656.0  australian children's music
# 1554     7Ljxd3OR0Lxj3MO8gxrKVE      707.0              children's folk
# ...                         ...        ...                          ...
# 1084277  6SLVfpC2sL1M6XF82UvWzv      687.0   preschool children's music
# 1087359  13QcQR3aMDTgC8jdNqSx4f     2175.0   preschool children's music
# 1089285  6V6io3ApRj18jjB2SORQsr      263.0             children's music
# 1103800  684XBlHktAb1iCz31fsr01       13.0    canadian children's music
# 1104018  5nFBJFMOmYCKtYIT30wd4M       17.0    canadian children's music
#
#                                 name  popularity  genre_count
# 144                   Honor Blackman          15            1
# 1501                   The Wayfarers          19            1
# 1525                    Patsy Biscoe          28            1
# 1548                     Don Spencer          33            1
# 1554                Franciscus Henri          33            1
# ...                              ...         ...          ...
# 1084277                   Nancy Gair          23            1
# 1087359                     GoNoodle          43            1
# 1089285  The Sausage Factory Singers          39            1
# 1103800         Kim and Jerry Brodey           1            1
# 1104018                  Paul Behnke           0            1
#
# [496 rows x 6 columns]

# %%
single_genre_artists_df
# Out:
#                              id  followers                        genres  \
# 45       0VLMVnVbJyJ4oyZs2L3Yl2       71.0                carnaval cadiz
# 46       0dt23bs4w8zx154C5xdVyl       63.0                carnaval cadiz
# 47       0pGhoB99qpEJEsBQxgaskQ       64.0                carnaval cadiz
# 48       3HDrX2OtSuXLW5dLR85uN3       53.0                carnaval cadiz
# 141      1OsJZxSshQD4BCg1VtwxsN      155.0           classical contralto
# ...                         ...        ...                           ...
# 1104318  70xqsSaFzoHsDjzaQnjvTW     2696.0  australian singer-songwriter
# 1104331  4fh2BIKYPFvXFsQLhaeVJp      309.0                      la indie
# 1104334  7akMsd2vb4xowNTehv3gsY      774.0                 indie rockism
# 1104336  35m7AJrUCtHYHyIUhCzmgi      205.0                 indie rockism
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0             deep acoustic pop
#
#                                  name  popularity  genre_count
# 45       Las Viudas De Los Bisabuelos           6            1
# 46                  Los De Capuchinos           5            1
# 47                 Los “Pofesionales”           7            1
# 48          Los Que No Paran De Rajar           6            1
# 141                      Anna Larsson          19            1
# ...                               ...         ...          ...
# 1104318                    Jack Carty          17            1
# 1104331                   Lone Kodiak          20            1
# 1104334                    The Str!ke           0            1
# 1104336                 Hunter Fraser           6            1
# 1104345               Right the Stars          18            1
#
# [213459 rows x 6 columns]

# %%
artists_genres_df.head()
# Out:
#                          id  followers                  genres  \
# 45   0VLMVnVbJyJ4oyZs2L3Yl2       71.0        [carnaval cadiz]
# 46   0dt23bs4w8zx154C5xdVyl       63.0        [carnaval cadiz]
# 47   0pGhoB99qpEJEsBQxgaskQ       64.0        [carnaval cadiz]
# 48   3HDrX2OtSuXLW5dLR85uN3       53.0        [carnaval cadiz]
# 136  22mLrN5fkppmuUPsHx6i2G       59.0  [classical harp, harp]
#
#                              name  popularity  genre_count
# 45   Las Viudas De Los Bisabuelos           6       298616
# 46              Los De Capuchinos           5       298616
# 47             Los “Pofesionales”           7       298616
# 48      Los Que No Paran De Rajar           6       298616
# 136                   Vera Dulova           3       298616

# %% [markdown]
# ### Daft Punk examples

# %%
DaftPunk = artists_df.loc[artists_df['name']=='Daft Punk']
DaftPunk
# Out:
#                             id  followers                       genres  \
# 144514  4tZwfgrHOc3mvqYlEYSvVi  7650304.0  ['electro', 'filter house']
#
#              name  popularity
# 144514  Daft Punk          86

# %%
DaftPunkID = DaftPunk.id.iloc[0]
print(id)
# Out:
# <built-in function id>

# %%
DaftPunkTracks = tracks_df[tracks_df['id_artists'].str.contains(DaftPunkID)]

# %%
DaftPunkTracks
# Out:
#                             id  \
# 68837   5N3FZ8eZ2mWwSWaJRAGHfS
# 70442   1pKYYY0dkg23sQQXi0Q5zN
# 70497   0MyY4WcN7DIfbSmp5yej5z
# 70607   5pgZpHqfv4TSomtkfGZGrG
# 70725   6hgBJPTHoDJyxydmtFWHKf
# ...                        ...
# 461958  5aZCwTIsfqv22p5bewcrgf
# 461976  5JSkyPoYHVT85NSd60PVEz
# 470494  0iYGI01MEFu9ohSNuMVpwL
# 564622  70RkgofUfQHLl2FT2Mx5zq
# 583511  1rn6JIHBuBZiwvA57jeoOB
#
#                                                      name  popularity  \
# 68837                                             Musique          54
# 70442                                    Around the World          78
# 70497                                             Da Funk          68
# 70607                                      Revolution 909          62
# 70725                                Rollin' & Scratchin'          58
# ...                                                   ...         ...
# 461958                                           Derezzed          49
# 461976                                   The Son of Flynn          48
# 470494  Around the World / Harder, Better, Faster, Str...          41
# 564622                                            Rinzler          50
# 583511                       Derezzed - Remixed by Avicii          52
#
#         duration_ms  explicit                  artists  \
# 68837        413600         0            ['Daft Punk']
# 70442        429533         0            ['Daft Punk']
# 70497        328680         0            ['Daft Punk']
# 70607        335027         0            ['Daft Punk']
# 70725        448627         0            ['Daft Punk']
# ...             ...       ...                      ...
# 461958       104120         0            ['Daft Punk']
# 461976        95227         0            ['Daft Punk']
# 470494       342627         0            ['Daft Punk']
# 564622       137636         0            ['Daft Punk']
# 583511       303947         0  ['Daft Punk', 'Avicii']
#
#                                                id_artists release_date  \
# 68837                          ['4tZwfgrHOc3mvqYlEYSvVi']         1995
# 70442                          ['4tZwfgrHOc3mvqYlEYSvVi']   1997-01-16
# 70497                          ['4tZwfgrHOc3mvqYlEYSvVi']   1997-01-16
# 70607                          ['4tZwfgrHOc3mvqYlEYSvVi']   1997-01-16
# 70725                          ['4tZwfgrHOc3mvqYlEYSvVi']   1997-01-16
# ...                                                   ...          ...
# 461958                         ['4tZwfgrHOc3mvqYlEYSvVi']   2010-12-03
# 461976                         ['4tZwfgrHOc3mvqYlEYSvVi']   2010-12-03
# 470494                         ['4tZwfgrHOc3mvqYlEYSvVi']   2007-11-19
# 564622                         ['4tZwfgrHOc3mvqYlEYSvVi']   2010-12-03
# 583511  ['4tZwfgrHOc3mvqYlEYSvVi', '1vCWHaC5f2uS3yhpwW...   2011-01-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 68837          0.821   0.885   11    -6.996     1       0.0811       0.00164
# 70442          0.956   0.795    7    -5.311     1       0.1500       0.00356
# 70497          0.806   0.700    0    -5.269     0       0.0752       0.00196
# 70607          0.745   0.716   11    -7.918     1       0.1360       0.02650
# 70725          0.822   0.791    1    -4.870     1       0.0414       0.00108
# ...              ...     ...  ...       ...   ...          ...           ...
# 461958         0.536   0.616    1   -10.019     1       0.0488       0.00159
# 461976         0.542   0.776    0   -17.679     0       0.0463       0.91400
# 470494         0.629   0.787    5    -8.399     0       0.0646       0.00152
# 564622         0.498   0.620    9   -14.651     1       0.0477       0.48300
# 583511         0.712   0.725    7    -7.317     0       0.1040       0.12400
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 68837              0.848    0.0851   0.8320  117.206               4
# 70442              0.889    0.0906   0.8410  121.294               4
# 70497              0.891    0.2670   0.8920  111.215               4
# 70607              0.846    0.2460   0.8280  126.527               4
# 70725              0.621    0.0567   0.2100  130.059               4
# ...                  ...       ...      ...      ...             ...
# 461958             0.773    0.1950   0.1010  119.988               4
# 461976             0.884    0.2620   0.0229  106.005               4
# 470494             0.359    0.2090   0.5810  125.998               4
# 564622             0.813    0.0947   0.0348   90.046               4
# 583511             0.834    0.2830   0.1560  127.985               4
#
# [93 rows x 20 columns]

# %%
ATW = tracks_df.loc[tracks_df['name']=='Harder, Better, Faster, Stronger']

# %%
ATW
# Out:
#                            id                              name  popularity  \
# 74454  5W3cjX2J3tjhG8zb6u0qHn  Harder, Better, Faster, Stronger          77
#
#        duration_ms  explicit        artists                  id_artists  \
# 74454       224693         0  ['Daft Punk']  ['4tZwfgrHOc3mvqYlEYSvVi']
#
#       release_date  danceability  energy  key  loudness  mode  speechiness  \
# 74454   2001-03-12         0.817   0.716    6    -8.898     0        0.144
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 74454        0.0427           0.00263     0.358    0.692  123.475
#
#        time_signature
# 74454               4

# %%
artists_df.head(3)
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0

# %%
popArtists = artists_df[artists_df['genres'].str.contains('pop')]
popArtists
# Out:
#                              id  followers  \
# 148      3zQdpHMTdJnV4aCzGqCBYK     3918.0
# 153      7frYUe4C7A42uZqCzD34Y4    53636.0
# 154      6acbdy69rtlv8m9EW31MYl    72684.0
# 155      72578usTM6Cj5qWsi471Nc   248568.0
# 158      7b6Ui7JVaBDEfZB9k6nHL0   701766.0
# ...                         ...        ...
# 1104201  3m7kkYCoZ7yaJB00zs0Jok     8424.0
# 1104298  3JST7Now2kQfkzE14z3tCi     4790.0
# 1104304  7DS32FizWDYqYkzR7K8u9n    31993.0
# 1104328  1q9C5XlekzXbRLIuLCDTre    90087.0
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0
#
#                                                     genres             name  \
# 148         ['classic persian pop', 'persian traditional']    Javad Maroufi
# 153         ['desi pop', 'punjabi hip hop', 'punjabi pop']          Sultaan
# 154      ['afro dancehall', 'afropop', 'azontobeats', '...            Phyno
# 155      ['filmi', 'indian folk', 'indian rock', 'kanna...      Raghu Dixit
# 158      ['desi pop', 'hindi indie', 'indian indie', 'i...  The Local Train
# ...                                                    ...              ...
# 1104201  ['alternative dance', 'dance-punk', 'electrofo...        Lo-Fi-Fnk
# 1104298          ['alternative pop rock', 'neon pop punk']      Action Item
# 1104304  ['alternative pop rock', 'neon pop punk', 'pix...     This Century
# 1104328                   ['social media pop', 'teen pop']     Brent Rivera
# 1104345                              ['deep acoustic pop']  Right the Stars
#
#          popularity
# 148              26
# 153              53
# 154              51
# 155              52
# 158              57
# ...             ...
# 1104201          21
# 1104298          10
# 1104304          33
# 1104328          33
# 1104345          18
#
# [44982 rows x 5 columns]

# %%
tracks_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
short_date = tracks_df[tracks_df['release_date'].str.len() ==4]
long_date = tracks_df[tracks_df['release_date'].str.len() != 4]

short_date['release_date'] = short_date['release_date']+ '-01-01'

tracks_dates_df = short_date.append(long_date)

tracks_dates_df['artists'] = tracks_dates_df.artists.apply(lambda x: x[2:-2].split("\'"+", "+"\'"))
tracks_dates_df['id_artists'] = tracks_dates_df.id_artists.apply(lambda x: x[2:-2].split("\'"+", "+"\'"))
# tracks_dates_df.artists[586553]
tracks_dates_df = tracks_dates_df.sort_values(by='release_date')
# Out:
# <ipython-input-26-3fca576ae001>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_date['release_date'] = short_date['release_date']+ '-01-01'

# %%
tracks_dates_df.loc[tracks_dates_df['explicit']==1]
# Out:
#                             id                             name  popularity  \
# 403     2l56fKIIrgfHWndcbkBAta                    The C00L Song           0
# 1054    6cnXo1yNldoXghTkWSshkW                      En Concreto           0
# 3307    3BBv75KQFMj9U1JLDFETbu                        Cops Come           0
# 3329    3LD3Rywf3LhBsgMKuNbOHE                         So Wrong           0
# 3010    0zeSDxsLftNTfxMnx3xDDj  Baking Dough (Money on My Mind)           0
# ...                        ...                              ...         ...
# 188830  3YXVO9D8bVAhbbjHJwnWWr                  Hear Me Calling           0
# 188829  2FtNANPWnAOKJVkoHLmiXu                     Lucid Dreams           0
# 188828  04pPqAbKKoAUCBdsM1KO6w           All Girls Are The Same           0
# 374824  7lSuxxU2VAoxKiJmeIzsiS         Si Tu Novio Te Deja Sola           0
# 188905  3dr7lQyaN9aJreEgXv4k1S         Si Tu Novio Te Deja Sola           0
#
#         duration_ms  explicit                artists  \
# 403          120309         1           [Dampfwalzi]
# 1054         185481         1            [Hot Doggo]
# 3307         256470         1              [Numba 9]
# 3329         251448         1              [Numba 9]
# 3010         191765         1              [Numba 9]
# ...             ...       ...                    ...
# 188830       189977         1           [Juice WRLD]
# 188829       239836         1           [Juice WRLD]
# 188828       165820         1           [Juice WRLD]
# 374824       243560         1  [J Balvin, Bad Bunny]
# 188905       243560         1  [J Balvin, Bad Bunny]
#
#                                               id_artists release_date  \
# 403                             [41GUFwc0gpqt495qHXpxFB]   1923-02-26
# 1054                            [5oHqWQeXiITZ7NP1MSN79N]   1924-03-03
# 3307                            [3Gyi5qhR9LAJ6VP9JskBSa]   1927-01-01
# 3329                            [3Gyi5qhR9LAJ6VP9JskBSa]   1927-01-01
# 3010                            [3Gyi5qhR9LAJ6VP9JskBSa]   1927-01-01
# ...                                                  ...          ...
# 188830                          [4MCBfE4596Uoi2O4DtmEMz]   2021-04-16
# 188829                          [4MCBfE4596Uoi2O4DtmEMz]   2021-04-16
# 188828                          [4MCBfE4596Uoi2O4DtmEMz]   2021-04-16
# 374824  [1vyhD5VmyZ7KMfW5gqLgo5, 4q3ewBCX7sLwd24euuV69X]   2021-04-16
# 188905  [1vyhD5VmyZ7KMfW5gqLgo5, 4q3ewBCX7sLwd24euuV69X]   2021-04-16
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 403            0.503   0.823    9   -12.871     0       0.0640      0.000243
# 1054           0.739   0.789    7    -7.272     1       0.1780      0.382000
# 3307           0.768   0.515    6   -10.937     1       0.1200      0.036800
# 3329           0.706   0.543    6   -11.893     0       0.4290      0.056800
# 3010           0.750   0.340    6   -10.906     0       0.4390      0.122000
# ...              ...     ...  ...       ...   ...          ...           ...
# 188830         0.699   0.687    7    -3.997     0       0.1060      0.308000
# 188829         0.511   0.566    6    -7.230     0       0.2000      0.349000
# 188828         0.673   0.529    0    -7.226     1       0.3060      0.076900
# 374824         0.717   0.460    3    -9.498     0       0.0711      0.521000
# 188905         0.717   0.460    3    -9.498     0       0.0711      0.521000
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 403             0.640000    0.4730    0.401   97.019               4
# 1054            0.001070    0.1160    0.657   90.040               4
# 3307            0.064000    0.2820    0.709   80.769               4
# 3329            0.000000    0.0729    0.310  153.587               4
# 3010            0.000000    0.2480    0.524   80.717               4
# ...                  ...       ...      ...      ...             ...
# 188830          0.000036    0.1210    0.499   88.933               4
# 188829          0.000000    0.3400    0.218   83.903               4
# 188828          0.000338    0.0856    0.203  161.991               4
# 374824          0.000000    0.0981    0.520  121.929               4
# 188905          0.000000    0.0981    0.520  121.929               4
#
# [25864 rows x 20 columns]

# %%
gp_sorted.head()
# Out:
#                    genres  popularity
# 237              basshall   80.666667
# 2778          turkish edm   80.000000
# 2533  south african house   80.000000
# 2755      trap venezolano   80.000000
# 46        alberta hip hop   78.500000

# %%
gp_sorted['genres_split'] = gp_sorted['genres'].str.split(" ")

# %%
gp_sorted
# Out:
#                       genres  popularity                genres_split
# 237                 basshall   80.666667                  [basshall]
# 2778             turkish edm   80.000000              [turkish, edm]
# 2533     south african house   80.000000     [south, african, house]
# 2755         trap venezolano   80.000000          [trap, venezolano]
# 46           alberta hip hop   78.500000         [alberta, hip, hop]
# ...                      ...         ...                         ...
# 2888     vintage spanish pop    0.000000     [vintage, spanish, pop]
# 828   deep progressive house    0.000000  [deep, progressive, house]
# 1428            israeli folk    0.000000             [israeli, folk]
# 2681               tajik pop    0.000000                [tajik, pop]
# 1723                medieval    0.000000                  [medieval]
#
# [2973 rows x 3 columns]

# %%
gp_sorted['genres_split'][0][1]
# Out:
# 'century'

# %%
genre_split_list = gp_sorted['genres_split'].tolist()

# %%
# genre_split_list
unique_genre_words = []
for row in genre_split_list:
    for x in range(len(row)):
        unique_genre_words.append(row[x])
    
genrewords_df= pd.DataFrame({'genre_words':unique_genre_words})

# %%
genre_split_list[1][0]
# Out:
# 'turkish'

# %%
len(genre_split_list)
# Out:
# 2973

# %%
genrewords_counts = genrewords_df.value_counts()

# %%
genrewords_counts.head(25)
# Out:
# genre_words
# pop            240
# indie          237
# rock           183
# metal          132
# classical      106
# hop            103
# hip            102
# jazz            96
# folk            80
# punk            66
# rap             64
# deep            56
# classic         54
# house           53
# piano           43
# japanese        40
# swedish         40
# canadian        38
# blues           37
# new             37
# italian         36
# modern          36
# alternative     34
# australian      33
# country         33
# dtype: int64
