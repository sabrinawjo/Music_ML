# %%
import pandas as pd
cluster_10thru14 = "../../Jake/azure_20Clusters_10thru14.csv"
cluster_15thru19 = "../../Jake/azure_20Clusters_15thru19.csv"
cluster_10thru14_df = pd.read_csv(cluster_10thru14)
cluster_15thru19_df = pd.read_csv(cluster_15thru19)

# %%
cluster_10thru14_df.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'Assignments',
#        'DistancesToClusterCenter no.0', 'DistancesToClusterCenter no.1',
#        'DistancesToClusterCenter no.2', 'DistancesToClusterCenter no.3',
#        'DistancesToClusterCenter no.4', 'DistancesToClusterCenter no.5',
#        'DistancesToClusterCenter no.6', 'DistancesToClusterCenter no.7',
#        'DistancesToClusterCenter no.8', 'DistancesToClusterCenter no.9',
#        'DistancesToClusterCenter no.10', 'DistancesToClusterCenter no.11',
#        'DistancesToClusterCenter no.12', 'DistancesToClusterCenter no.13',
#        'DistancesToClusterCenter no.14', 'DistancesToClusterCenter no.15',
#        'DistancesToClusterCenter no.16', 'DistancesToClusterCenter no.17',
# ...

# %%
c_10thru14_df = cluster_10thru14_df[['popularity', 'explicit',
    'danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'time_signature', 'Assignments']]
c_10thru14_df
# Out:
#        popularity  explicit  danceability  energy  key  loudness  mode  \
# 0              38         0         0.654   0.571    1    -3.786     1
# 1              44         0         0.570   0.556   10    -8.903     1
# 2              36         0         0.687   0.754    5   -11.406     0
# 3              32         0         0.338   0.251    5   -17.826     1
# 4              32         0         0.649   0.802    2    -7.947     1
# ...           ...       ...           ...     ...  ...       ...   ...
# 83673          27         0         0.584   0.107    7   -17.941     1
# 83674          12         0         0.275   0.377    0   -18.386     0
# 83675          17         0         0.363   0.279    3   -15.057     1
# 83676          10         0         0.309   0.426   10    -7.498     1
# 83677          55         0         0.387   0.455    7    -7.828     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
c_grouped_10thru14=c_10thru14_df.groupby('Assignments').mean()
c_grouped_10thru14
# Out:
#              popularity  explicit  danceability    energy       key  \
# Assignments
# 10            28.535566  0.033323      0.432435  0.608476  5.266902
# 11            29.116689  0.021849      0.553529  0.607810  5.195284
# 12            11.142632  0.016069      0.516294  0.549899  5.117360
# 13            42.254524  0.059983      0.634741  0.617950  5.322463
# 14            54.694712  0.137426      0.516799  0.683963  5.383993
#
#               loudness      mode  speechiness  acousticness  instrumentalness  \
# Assignments
# 10           -9.009179  0.713874     0.107604      0.375835          0.075896
# 11           -9.436780  0.668208     0.077680      0.353607          0.077401
# 12          -10.589377  0.670169     0.079415      0.478384          0.142540
# 13           -8.739167  0.636518     0.089089      0.333567          0.062150
# 14           -6.938529  0.641832     0.113691      0.259926          0.041539
#
#              liveness   valence       tempo  time_signature
# ...

# %%
# Cluster 10:
#      Higher values: Mode 0.7139, Speechiness 0.1076, Valence 0.6328, Tempo 195.9344
#      Lower  values: Danceability 0.4324, Time_signature 3.7842
# Cluster 11:
#      Higher values: 
#      Lower  values: Speechiness 0.077680, Valence 0.5665
# Cluster 12: 
#      Higher values: Acousticness 0.478384, Instrumentalness 0.1425
#      Lower  values: Loudness -10.5894 (quiet), Explicit 0.0161, Energy 0.5499, Speechiness 0.0794
# Cluster 13:
#      Higher values: Danceability 0.6347
#      Lower  values: Mode 0.6365, Tempo 105.6926
# Cluster 14: (populer 54.69)
#      Higher values: Explicit 0.1374, Energy 0.6840, Cloudness -6.9385 (loud), Speechiness 0.1137
#      Lower  values: acousticness 0.2599, Instrumentalness 0.0415, Valence 0.5625

# %%
df["loudness_scale"] = 1-(df["loudness"]/df["loudness"].min())
df["tempo_scale"] = df["tempo"]/df["tempo"].max()
df["duration_scale"] = df["duration_ms"]/df["duration_ms"].max()
df["popularity_scale"] = df["popularity"]/df["popularity"].max()

# %%
cluster_15thru19_df.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'Assignments',
#        'DistancesToClusterCenter no.0', 'DistancesToClusterCenter no.1',
#        'DistancesToClusterCenter no.2', 'DistancesToClusterCenter no.3',
#        'DistancesToClusterCenter no.4', 'DistancesToClusterCenter no.5',
#        'DistancesToClusterCenter no.6', 'DistancesToClusterCenter no.7',
#        'DistancesToClusterCenter no.8', 'DistancesToClusterCenter no.9',
#        'DistancesToClusterCenter no.10', 'DistancesToClusterCenter no.11',
#        'DistancesToClusterCenter no.12', 'DistancesToClusterCenter no.13',
#        'DistancesToClusterCenter no.14', 'DistancesToClusterCenter no.15',
#        'DistancesToClusterCenter no.16', 'DistancesToClusterCenter no.17',
# ...

# %%
c_15thru19_df = cluster_15thru19_df[['popularity', 'explicit',
    'danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'time_signature', 'Assignments']]
c_15thru19_df
# Out:
#        popularity  explicit  danceability  energy  key  loudness  mode  \
# 0              28         0         0.515   0.735   11    -6.955     0
# 1               3         0         0.356   0.250    2   -10.914     0
# 2              11         0         0.621   0.215    7   -12.352     0
# 3               7         0         0.418   0.275    5   -12.825     0
# 4              19         0         0.537   0.940    2    -5.981     1
# ...           ...       ...           ...     ...  ...       ...   ...
# 75624           9         0         0.192   0.143    4   -21.266     0
# 75625          16         0         0.374   0.582    0   -10.081     0
# 75626          10         0         0.535   0.852   11    -4.971     0
# 75627          43         0         0.427   0.409    5   -10.060     1
# 75628          38         0         0.527   0.783    7    -7.825     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
c_grouped_15thru19=c_15thru19_df.groupby('Assignments').mean()
c_grouped_15thru19
# Out:
#              popularity  explicit  danceability    energy       key  \
# Assignments
# 15             6.554546  0.014280      0.519105  0.409261  5.158133
# 16             8.804631  0.019874      0.441223  0.477733  5.179151
# 17            32.286050  0.037995      0.489601  0.645385  5.213618
# 18            31.509533  0.009939      0.451096  0.313418  5.127992
# 19             6.797281  0.009271      0.581812  0.430632  5.155262
#
#               loudness      mode  speechiness  acousticness  instrumentalness  \
# Assignments
# 15          -12.366861  0.679937     0.094598      0.674087          0.173206
# 16          -11.362952  0.689603     0.112397      0.580188          0.152558
# 17           -8.851394  0.665702     0.109125      0.323252          0.065620
# 18          -16.022896  0.663895     0.292287      0.683891          0.221973
# 19          -12.094609  0.675305     0.090026      0.649996          0.188617
#
#              liveness   valence       tempo  time_signature
# ...

# %%
# Cluster 15: (populer 6.5545)
#      Higher values: Acousticness 0.6741
#      Lower  values: speechiness 0.0946
# Cluster 16:
#      Higher values: Tempo 174.0106
#      Lower  values: Danceability 0.4412
# Cluster 17: 
#      Higher values: Explicit 0.0380, Energy 0.6454, Loudness -8.8514 (loud)
#      Lower  values: Acousticness 0.3233, Instrumentalness 0.0656
# Cluster 18:
#      Higher values: Speechiness 0.2923, Acousticness 0.6839, Instrumentalness 0.2220
#      Lower  values: Explicit 0.0099, Energy 0.3134, Loudness -16.0229 (quiet), Tempo 59.5494
# Cluster 19: (populer 6.7973)
#      Higher values: Danceability 0.5818
#      Lower  values: Explicit 0.0093, Speechiness 0.0900
