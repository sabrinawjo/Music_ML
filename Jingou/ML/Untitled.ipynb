# %%
import pandas as pd
path = "C:/Users/jingo/UCIBootCamp/calendar/Music_ML/Jingou/ML/azureOutputAttributes/azureOutputAttributes.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#         Unnamed: 0                      id  \
# 0                0  07A5yehtSnoedViJAZkNnc
# 1                1  08FmqUhxtyLTn6pAh6bk45
# 2                2  08y9GfoqCWfOGsKdwojr5e
# 3                3  0BRXJHRNGQ3W4v9frnSfhu
# 4                4  0IA0Hju8CAgYfV1hwhidBH
# ...            ...                     ...
# 549049      549049  5rgu12WBIHQtvej2MdHSH0
# 549050      549050  0NuWgxEp51CutD2pJoF4OM
# 549051      549051  27Y1N4Q4U3EfDU5Ubw8ws2
# 549052      549052  45XJsGpFTyzbzeWK8VzR8S
# 549053      549053  5Ocn6dZ3BJFPWh4ylwFXtn
#
#                                       name  \
# 0       Vivo para Quererte - Remasterizado
# 1            El Prisionero - Remasterizado
# 2                      Lady of the Evening
# 3                                Ave Maria
# 4                                  La Java
# ...                                    ...
# 549049                                 云与海
# 549050                               blind
# 549051           What They'll Say About Us
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
df.to_sql('users', con=engine)

# %%
engine.execute('''select name from users where Assignments = 0 order by random() limit 5 ''').fetchall()
# Out:
# [('Sha Ti Skasam Gaza',),
#  ("I've Seen All Good People: a. Your Move, b. All Good People - 2003 Remaster",),
#  ('After Hours',),
#  ('Balisong',),
#  ('She Treats Me Well',)]
