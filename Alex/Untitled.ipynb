# %%
import pandas as pd
import matplotlib as plt
import numpy

# %%
main_data = pd.read_csv("../Resources/archive/data_o.csv")
main_data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
genre_data =pd.read_csv("../Resources/archive/data_by_genres_o.csv")
# genre_data["genres"].value_counts()
# genre_data.loc[genre_data['genres']=="blues"]
genre_data
# Out:
#       mode                  genres  acousticness  danceability   duration_ms  \
# 0        1  21st century classical      0.979333      0.162883  1.602977e+05
# 1        1                   432hz      0.494780      0.299333  1.048887e+06
# 2        1                   8-bit      0.762000      0.712000  1.151770e+05
# 3        1                      []      0.651417      0.529093  2.328809e+05
# 4        1              a cappella      0.676557      0.538961  1.906285e+05
# ...    ...                     ...           ...           ...           ...
# 2968     1                    zolo      0.222625      0.547082  2.580991e+05
# 2969     0                 zouglou      0.161000      0.863000  2.063200e+05
# 2970     1                    zouk      0.263261      0.748889  3.060728e+05
# 2971     0            zurich indie      0.993000      0.705667  1.984173e+05
# 2972     1                  zydeco      0.421038      0.629409  1.716717e+05
#
# ...

# %%
genre_data.loc[genre_data['genres']=='pop']
# Out:
#       mode genres  acousticness  danceability    duration_ms    energy  \
# 2170     1    pop      0.276873      0.628349  216336.259142  0.611041
#
#       instrumentalness  liveness  loudness  speechiness       tempo   valence  \
# 2170          0.025298  0.175073 -6.977413     0.085784  119.649666  0.479474
#
#       popularity  key
# 2170   60.745909    1

# %%
genre_data.loc[lambda row : row['genres'].str.startswith('synth')]
# Out:
#       mode      genres  acousticness  danceability    duration_ms    energy  \
# 2668     1  synth funk      0.151356      0.714669  300953.372843  0.700846
# 2669     1    synthpop      0.148397      0.634949  263461.769635  0.682315
# 2670     1   synthwave      0.157904      0.563652  248248.869565  0.706304
#
#       instrumentalness  liveness   loudness  speechiness       tempo  \
# 2668          0.063522  0.225344  -9.357442     0.076465  116.689170
# 2669          0.132777  0.196827 -10.435089     0.047168  121.507293
# 2670          0.465857  0.161930  -7.281261     0.043913  122.583000
#
#        valence  popularity  key
# 2668  0.727586   35.840619   11
# 2669  0.662531   42.511350    9
# 2670  0.498496   52.000000   10

# %%
genre_data.loc[genre_data['genres']=='synth-pop']
# Out:
# Empty DataFrame
# Columns: [mode, genres, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, speechiness, tempo, valence, popularity, key]
# Index: []

# %%
genre_data.head(5)
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
genre_data['genres'].value_counts()
# Out:
# vallenato                   1
# social media pop            1
# psychobilly                 1
# british modern classical    1
# romantico                   1
#                            ..
# austin americana            1
# musica andina colombiana    1
# melodic deathcore           1
# australian talent show      1
# middle earth                1
# Name: genres, Length: 2973, dtype: int64

# %%
genre_data['popularity']
# Out:
# 0       27.833333
# 1       52.500000
# 2       48.000000
# 3       20.859882
# 4       45.820071
#           ...
# 2968    33.778943
# 2969    58.000000
# 2970    46.666667
# 2971     0.000000
# 2972    30.261905
# Name: popularity, Length: 2973, dtype: float64

# %%
genre_data.loc[lambda row : row['genres'].str.startswith('nintendo')]
# Out:
#       mode        genres  acousticness  danceability    duration_ms    energy  \
# 1964     0  nintendocore      0.055703      0.443445  231674.497899  0.880043
#
#       instrumentalness  liveness  loudness  speechiness      tempo   valence  \
# 1964           0.08597  0.224086 -5.475074     0.112972  139.46998  0.397604
#
#       popularity  key
# 1964   46.531513    5

# %%
genre_list_df = pd.read_csv("../Resources/genre_list.csv")
genre_list_df.loc[genre_list_df["Genre"] == "Rock"] = "rock"

genre_list_df.loc[genre_list_df["Genre"] == "Hip hop music"] = "hip hop" 
genre_list_df.loc[genre_list_df["Genre"] == "Pop music"] = "pop" 
genre_list_df.loc[genre_list_df["Genre"] == "Jazz"] = "jazz" 
genre_list_df.loc[genre_list_df["Genre"] == "Country music"] = "country" 
genre_list_df.loc[genre_list_df["Genre"] == "Electronic dance music"] = "electro house" 
genre_list_df.loc[genre_list_df["Genre"] == "Rhythm and blues"] = "r&b" 
genre_list_df.loc[genre_list_df["Genre"] == "Blues"] = "blues" 
genre_list_df.loc[genre_list_df["Genre"] == "Heavy metal"] = "metal" 
genre_list_df.loc[genre_list_df["Genre"] == "Folk music"] = "folk" 
genre_list_df.loc[genre_list_df["Genre"] == "Dance music"] = "dance pop" 
genre_list_df.loc[genre_list_df["Genre"] == "Classical music"] = "classical" 
genre_list_df.loc[genre_list_df["Genre"] == "Electronic music"] = "electro" 
genre_list_df.loc[genre_list_df["Genre"] == "Soul music"] = "soul" 
genre_list_df.loc[genre_list_df["Genre"] == "Punk rock"] = "punk" 
genre_list_df.loc[genre_list_df["Genre"] == "Alternative rock"] = "alternative rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Pop rock"] = "pop rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Singing"] = "singer-songwriter" 
genre_list_df.loc[genre_list_df["Genre"] == "Funk"] = "funk" 
genre_list_df.loc[genre_list_df["Genre"] == "Reggae"] = "reggae" 
genre_list_df.loc[genre_list_df["Genre"] == "Disco"] = "disco" 
genre_list_df.loc[genre_list_df["Genre"] == "Indie rock"] = "indie rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Techno"] = "techno" 
genre_list_df.loc[genre_list_df["Genre"] == "House music"] = "house" 
genre_list_df.loc[genre_list_df["Genre"] == "K-pop"] = "k-pop" 
genre_list_df.loc[genre_list_df["Genre"] == "Gospel music"] = "gospel" 
genre_list_df.loc[genre_list_df["Genre"] == "Instrumental"] = "instrumental math rock"
genre_list_df.loc[genre_list_df["Genre"] == "Grunge"] = "grunge" 
genre_list_df.loc[genre_list_df["Genre"] == "Orchestra"] = "orchestra" 
genre_list_df.loc[genre_list_df["Genre"] == "Reggaeton"] = "reggaeton" 
genre_list_df.loc[genre_list_df["Genre"] == "Music of Latin America"] = "latin" 
genre_list_df.loc[genre_list_df["Genre"] == "Rapping"] = "rap"
genre_list_df.loc[genre_list_df["Genre"] == "Progressive rock"] = "progressive rock" 
genre_list_df.loc[genre_list_df["Genre"] == "New wave"] = "new wave" 
genre_list_df.loc[genre_list_df["Genre"] == "Hard rock"] = "hard rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Psychedelic music"] = "psychedelic doom" 
genre_list_df.loc[genre_list_df["Genre"] == "Emo"] = "emo" 
genre_list_df.loc[genre_list_df["Genre"] == "Trap music"] = "trap" 
genre_list_df.loc[genre_list_df["Genre"] == "Ska"] = "ska" 
genre_list_df.loc[genre_list_df["Genre"] == "Classic rock"] = "classic rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Opera"] = "opera" 
genre_list_df.loc[genre_list_df["Genre"] == "Psychedelic rock"] = "psychedelic rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Soundtrack"] = "soundtrack" 
genre_list_df.loc[genre_list_df["Genre"] == "Trance music"] = "trance" 
genre_list_df.loc[genre_list_df["Genre"] == "Synth-pop"] = "synthpop" 
genre_list_df.loc[genre_list_df["Genre"] == "World music"] = "world" 
genre_list_df.loc[genre_list_df["Genre"] == "Country rock"] = "country rock" 
genre_list_df.loc[genre_list_df["Genre"] == "Music of the United States"] = "nintendocore" 
genre_list_df.loc[genre_list_df["Genre"] == "Jazz fusion"] = "jazz fusion" 
genre_list_df.loc[genre_list_df["Genre"] == "Popular music"] = "mongolian pop" 
genre_list_df.loc[genre_list_df["Genre"] == "Ambient music"] = "ambient" 
genre_list_df
# Out:
#                      Genre
# 0                     rock
# 1            mongolian pop
# 2                  hip hop
# 3                      pop
# 4                     jazz
# 5                  country
# 6            electro house
# 7                      r&b
# 8                    blues
# 9                    metal
# 10                    folk
# 11               dance pop
# 12               classical
# 13                 electro
# 14                    soul
# 15                    punk
# 16        alternative rock
# 17                pop rock
# 18       singer-songwriter
# 19                    funk
# 20                  reggae
# 21                   disco
# 22              indie rock
# 23                  techno
# 24                   house
# 25                   k-pop
# 26                  gospel
# 27  instrumental math rock
# 28                  grunge
# 29               orchestra
# 30               reggaeton
# 31                   latin
# 32                     rap
# ...

# %%
merged_genre = genre_data.merge(genre_list_df, left_on=genre_data["genres"], right_on=genre_list_df["Genre"])
cleaned_merged_genre = merged_genre.drop(["key_0","Genre"], axis=1)
cleaned_merged_genre
# Out:
#     mode                  genres  acousticness  danceability    duration_ms  \
# 0      1        alternative rock      0.157059      0.478342  240339.441200
# 1      1                 ambient      0.673274      0.335075  350676.825389
# 2      1                   blues      0.591314      0.582693  230965.360811
# 3      1            classic rock      0.266815      0.525433  254238.060515
# 4      1               classical      0.923085      0.314425  312001.151573
# 5      1                 country      0.317107      0.589586  213907.400941
# 6      1            country rock      0.360140      0.562638  235107.242199
# 7      1               dance pop      0.183687      0.651812  229190.833887
# 8      1                   disco      0.255098      0.664752  287209.141669
# 9      1                 electro      0.120610      0.795599  303464.484030
# 10     1           electro house      0.075707      0.635286  236145.071358
# ...

# %%
cleaned_merged_genre.to_csv('../Resources/top_51_genres.csv', index = False)

# %%
artist_data = pd.read_csv("../Resources/archive/data_by_artist_o.csv")
artist = artist_data["artists"].unique()
artist_data.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# ...

# %%
artist_and_song =

# %%
main_data.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
year_data = pd.read_csv("../Resources/archive/data_by_year.csv")
year_data
# Out:
#      year  acousticness  danceability    duration_ms    energy  \
# 0    1920      0.631242      0.515750  238092.997135  0.418700
# 1    1921      0.862105      0.432171  257891.762821  0.241136
# 2    1922      0.828934      0.575620  140135.140496  0.226173
# 3    1923      0.957247      0.577341  177942.362162  0.262406
# 4    1924      0.940200      0.549894  191046.707627  0.344347
# ..    ...           ...           ...            ...       ...
# 97   2017      0.207413      0.580475  243402.249536  0.686392
# 98   2018      0.233836      0.602731  227073.140015  0.659552
# 99   2019      0.261344      0.603101  225463.326320  0.629781
# 100  2020      0.202303      0.605285  218977.482767  0.674247
# 101  2021      0.340253      0.652488  222760.028261  0.578896
#
#      instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0            0.354219  0.216049 -12.654020     0.082984  113.226900  0.498210
# ...

# %%
keys_df = pd.read_csv("../Resources/Musical_Keys.csv")
keys_df
# Out:
#     Unnamed: 0  Key MusicalKey
# 0            0    0          C
# 1            1    1         Db
# 2            2    2          D
# 3            3    3         Eb
# 4            4    4          E
# 5            5    5          F
# 6            6    6      F#/Gb
# 7            7    7          G
# 8            8    8         Ab
# 9            9    9          A
# 10          10   10         Bb
# 11          11   11          B

# %%
# # dropping weird unnamed:0 column
# keys_df = keys_df.drop(keys_df.columns[0], axis=1)
keys_df = pd.read_csv("../Resources/cleaned_Musical_Keys.csv")

keys_df = keys_df.drop(keys_df.columns[0], axis=1)

keys_df
# Out:
#     Key MusicalKey
# 0     0          C
# 1     1         Db
# 2     2          D
# 3     3         Eb
# 4     4          E
# 5     5          F
# 6     6      F#/Gb
# 7     7          G
# 8     8         Ab
# 9     9          A
# 10   10         Bb
# 11   11          B

# %%
# keys_df.to_csv("../Resources/cleaned_Musical_Keys.csv")

# %%
main_data = main_data.rename(columns = {"key":"Key"})

# %%
main_data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
merged_keys_df = pd.merge(keys_df, main_data, on="Key")
# pd.merge(<df1>,<df2>, on=<column(s)>, how=<type of join>)
merged_keys_df
# Out:
#         Key MusicalKey  valence  year  acousticness  \
# 0         0          C    0.406  1921        0.9960
# 1         0          C    0.403  1921        0.9920
# 2         0          C    0.651  1921        0.9920
# 3         0          C    0.275  1921        0.5970
# 4         0          C    0.574  1921        0.9950
# ...     ...        ...      ...   ...           ...
# 170648   11          B    0.394  2020        0.6960
# 170649   11          B    0.514  2020        0.1290
# 170650   11          B    0.632  2020        0.3550
# 170651   11          B    0.547  2020        0.0851
# 170652   11          B    0.210  2020        0.9680
#
#                                                   artists  danceability  \
# 0                                      ['John McCormack']         0.518
# 1                                     ['Ignacio Corsini']         0.332
# 2                                   ['Maurice Chevalier']         0.522
# ...

# %%
merged_keys_df.to_csv("../Resources/Clean_Main_Merged_data")

# %%
merged_keys_df.loc[merged_keys_df["popularity"]>=80].count()
# Out:
# Key                 688
# MusicalKey          688
# valence             688
# year                688
# acousticness        688
# artists             688
# danceability        688
# duration_ms         688
# energy              688
# explicit            688
# id                  688
# instrumentalness    688
# liveness            688
# loudness            688
# mode                688
# name                688
# popularity          688
# release_date        688
# speechiness         688
# tempo               688
# dtype: int64

# %%
merged_df = pd.read_csv("../Resources/cleaned_Musical_Keys.csv")

# %%
merged_df
# Out:
#     Unnamed: 0  Key MusicalKey
# 0            0    0          C
# 1            1    1         Db
# 2            2    2          D
# 3            3    3         Eb
# 4            4    4          E
# 5            5    5          F
# 6            6    6      F#/Gb
# 7            7    7          G
# 8            8    8         Ab
# 9            9    9          A
# 10          10   10         Bb
# 11          11   11          B

# %%
main_df =  pd.read_csv("../Resources/Clean_Main_Merged_data")
main_df
# Out:
#         Unnamed: 0  Key MusicalKey  valence  year  acousticness  \
# 0                0    0          C    0.406  1921        0.9960
# 1                1    0          C    0.403  1921        0.9920
# 2                2    0          C    0.651  1921        0.9920
# 3                3    0          C    0.275  1921        0.5970
# 4                4    0          C    0.574  1921        0.9950
# ...            ...  ...        ...      ...   ...           ...
# 170648      170648   11          B    0.394  2020        0.6960
# 170649      170649   11          B    0.514  2020        0.1290
# 170650      170650   11          B    0.632  2020        0.3550
# 170651      170651   11          B    0.547  2020        0.0851
# 170652      170652   11          B    0.210  2020        0.9680
#
#                                                   artists  danceability  \
# 0                                      ['John McCormack']         0.518
# ...

# %%
artists_df = pd.read_csv("../Resources/archive/data_by_artist_o.csv")
artists_df["duration_s"] = artists_df["duration_ms"] /1000
artists_df["duration_min"] = round(artists_df["duration_s"]/60, 2)

# %%
artists_df.to_csv("../Resources/Clean_Artists.csv")

# %%
artist_df = pd.read_csv("../Resources/Clean_Artists.csv")

# %%
artist_df
# Out:
#        mode  count  acousticness  \
# 0         1      9      0.590111
# 1         1     26      0.862538
# 2         1      7      0.856571
# 3         1     27      0.884926
# 4         1      7      0.510714
# ...     ...    ...           ...
# 28675     1      2      0.512000
# 28676     0      2      0.541000
# 28677     1     11      0.785455
# 28678     1      2      0.381000
# 28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
# ...                                                  ...           ...
# ...

# %%
artist_df["tempo"] = round(artist_df["tempo"],2)
artist_df["popularity"] = round(artist_df["popularity"],2)

# %%
artist_df
# Out:
#        mode  count  acousticness  \
# 0         1      9      0.590111
# 1         1     26      0.862538
# 2         1      7      0.856571
# 3         1     27      0.884926
# 4         1      7      0.510714
# ...     ...    ...           ...
# 28675     1      2      0.512000
# 28676     0      2      0.541000
# 28677     1     11      0.785455
# 28678     1      2      0.381000
# 28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
# ...                                                  ...           ...
# ...

# %%
artist_df.to_csv("../Resources/Clean_Artists.csv")

# %%
artist_df = pd.read_csv("../Resources/Clean_Artists.csv")
artist_df
# Out:
#        Unnamed: 0  mode  count  acousticness  \
# 0               0     1      9      0.590111
# 1               1     1     26      0.862538
# 2               2     1      7      0.856571
# 3               3     1     27      0.884926
# 4               4     1      7      0.510714
# ...           ...   ...    ...           ...
# 28675       28675     1      2      0.512000
# 28676       28676     0      2      0.541000
# 28677       28677     1     11      0.785455
# 28678       28678     1      2      0.381000
# 28679       28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# ...

# %%
loud_min = artist_df["loudness"].min()
loud_min
# Out:
# -60.0

# %%
artist_df["loudness_scale"] = round(1 - (artist_df["loudness"]/loud_min),2)
artist_df
# Out:
#        Unnamed: 0  mode  count  acousticness  \
# 0               0     1      9      0.590111
# 1               1     1     26      0.862538
# 2               2     1      7      0.856571
# 3               3     1     27      0.884926
# 4               4     1      7      0.510714
# ...           ...   ...    ...           ...
# 28675       28675     1      2      0.512000
# 28676       28676     0      2      0.541000
# 28677       28677     1     11      0.785455
# 28678       28678     1      2      0.381000
# 28679       28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# ...

# %%
artist_df.to_csv("../Resources/Clean_Artists.csv")

# %%
new_df = pd.read_csv("../Resources/Clean_Artists.csv")
new_df
# Out:
#        Unnamed: 0  Unnamed: 0.1  mode  count  acousticness  \
# 0               0             0     1      9      0.590111
# 1               1             1     1     26      0.862538
# 2               2             2     1      7      0.856571
# 3               3             3     1     27      0.884926
# 4               4             4     1      7      0.510714
# ...           ...           ...   ...    ...           ...
# 28675       28675         28675     1      2      0.512000
# 28676       28676         28676     0      2      0.541000
# 28677       28677         28677     1     11      0.785455
# 28678       28678         28678     1      2      0.381000
# 28679       28679         28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# ...

# %%
new_df = new_df.drop(new_df.columns[0], axis=1)

# %%
new_df = new_df.drop(new_df.columns[0], axis=1)

# %%
new_df
# Out:
#        mode  count  acousticness  \
# 0         1      9      0.590111
# 1         1     26      0.862538
# 2         1      7      0.856571
# 3         1     27      0.884926
# 4         1      7      0.510714
# ...     ...    ...           ...
# 28675     1      2      0.512000
# 28676     0      2      0.541000
# 28677     1     11      0.785455
# 28678     1      2      0.381000
# 28679     1      2      0.568000
#
#                                                  artists  danceability  \
# 0                       "Cats" 1981 Original London Cast      0.467222
# 1                              "Cats" 1983 Broadway Cast      0.441731
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
# ...                                                  ...           ...
# ...

# %%
new_df.to_csv("../Resources/Clean_artists.csv", index=False)

# %%
genre_df = pd.read_csv("../Resources/archive/genres.csv")
genre_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-438ef43de3a1> in <module>
# ----> 1 genre_df = pd.read_csv("../Resources/archive/genres.csv")
#       2 genre_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...
