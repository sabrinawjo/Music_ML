# %%
import pandas as pd

# %%
c_zero_four = pd.read_csv("../../Jake/azure_20Clusters_0thru4.csv")
c_zero_four
# Out:
#                                               id_artists  \
# 0      ['2OJEUmIIPsTAUjil4dOz70', '35AgMyuKAQIoMJZEp3...
# 1                             ['23zg3TcAtWQy7J6upgbUnj']
# 2                             ['1JbemQ1fPt2YmSLjAFhPBv']
# 3                             ['60VZiaKmhyt8EmMW6K68QY']
# 4      ['0aFGod7DM6b3O5l1AmvFwK', '4OTsinUjquvK195Hgs...
# ...                                                  ...
# 90858                         ['2qWK8K2Jfh67UqtwY8tCW6']
# 90859                         ['2C6i0I5RiGzDKN9IAF8reh']
# 90860  ['2UqjDAXnDxejEyE0CzfUrZ', '0cXLIzzlld2GM0hBiY...
# 90861                         ['3hN3iJMbbBmqBSAMx5veDa']
# 90862  ['7cjW4lxHsJy6K6j0gpxKEF', '59N28aG3GjDHbmIrjD...
#
#                            id  \
# 0      6aQeKAkwLkcdBkEUBS7eXU
# 1      5zdUc1JRCImBYcDWgvFNpE
# 2      5x6K9Bz1StBFAWTNMRAwmn
# 3      6ZgU0LOK4oRKYf09cJ5oe8
# 4      5lSNAZZ8rqFmjrIhUidOFv
# ...                       ...
# 90858  4ORf8PPjeY3YYjVDDYn9ke
# ...

# %%
c_zero_four.columns
# Out:
# Index(['id_artists', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'release_date', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'Assignments',
#        'DistancesToClusterCenter no.0', 'DistancesToClusterCenter no.1',
#        'DistancesToClusterCenter no.2', 'DistancesToClusterCenter no.3',
#        'DistancesToClusterCenter no.4', 'DistancesToClusterCenter no.5',
#        'DistancesToClusterCenter no.6', 'DistancesToClusterCenter no.7',
#        'DistancesToClusterCenter no.8', 'DistancesToClusterCenter no.9',
#        'DistancesToClusterCenter no.10', 'DistancesToClusterCenter no.11',
#        'DistancesToClusterCenter no.12', 'DistancesToClusterCenter no.13',
#        'DistancesToClusterCenter no.14', 'DistancesToClusterCenter no.15',
#        'DistancesToClusterCenter no.16', 'DistancesToClusterCenter no.17',
# ...

# %%
# Drop the null columns where all values are null
c_zero_four = c_zero_four.dropna(axis='columns', how='all')
# Drop the null rows
c_zero_four = c_zero_four.dropna()
c_zero_four
# Out:
#                                               id_artists  \
# 0      ['2OJEUmIIPsTAUjil4dOz70', '35AgMyuKAQIoMJZEp3...
# 1                             ['23zg3TcAtWQy7J6upgbUnj']
# 2                             ['1JbemQ1fPt2YmSLjAFhPBv']
# 3                             ['60VZiaKmhyt8EmMW6K68QY']
# 4      ['0aFGod7DM6b3O5l1AmvFwK', '4OTsinUjquvK195Hgs...
# ...                                                  ...
# 90858                         ['2qWK8K2Jfh67UqtwY8tCW6']
# 90859                         ['2C6i0I5RiGzDKN9IAF8reh']
# 90860  ['2UqjDAXnDxejEyE0CzfUrZ', '0cXLIzzlld2GM0hBiY...
# 90861                         ['3hN3iJMbbBmqBSAMx5veDa']
# 90862  ['7cjW4lxHsJy6K6j0gpxKEF', '59N28aG3GjDHbmIrjD...
#
#                            id  \
# 0      6aQeKAkwLkcdBkEUBS7eXU
# 1      5zdUc1JRCImBYcDWgvFNpE
# 2      5x6K9Bz1StBFAWTNMRAwmn
# 3      6ZgU0LOK4oRKYf09cJ5oe8
# 4      5lSNAZZ8rqFmjrIhUidOFv
# ...                       ...
# 90858  4ORf8PPjeY3YYjVDDYn9ke
# ...

# %%
null_columns = c_zero_four.columns[c_zero_four.isnull().any()]
c_zero_four[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
c_zero_four = c_zero_four.drop(['id_artists','id','name','release_date','duration_ms','artists','DistancesToClusterCenter no.0', 'DistancesToClusterCenter no.1',
       'DistancesToClusterCenter no.2', 'DistancesToClusterCenter no.3',
       'DistancesToClusterCenter no.4', 'DistancesToClusterCenter no.5',
       'DistancesToClusterCenter no.6', 'DistancesToClusterCenter no.7',
       'DistancesToClusterCenter no.8', 'DistancesToClusterCenter no.9',
       'DistancesToClusterCenter no.10', 'DistancesToClusterCenter no.11',
       'DistancesToClusterCenter no.12', 'DistancesToClusterCenter no.13',
       'DistancesToClusterCenter no.14', 'DistancesToClusterCenter no.15',
       'DistancesToClusterCenter no.16', 'DistancesToClusterCenter no.17',
       'DistancesToClusterCenter no.18', 'DistancesToClusterCenter no.19'], axis=1)

c_zero_four.count()
# Out:
# popularity          90818
# explicit            90818
# danceability        90818
# energy              90818
# key                 90818
# loudness            90818
# mode                90818
# speechiness         90818
# acousticness        90818
# instrumentalness    90818
# liveness            90818
# valence             90818
# tempo               90818
# time_signature      90818
# Assignments         90818
# dtype: int64

# %%
c_zero_four
# Out:
#        popularity  explicit  danceability  energy  key  loudness  mode  \
# 0               0         0         0.694  0.3030    0   -16.303     0
# 1              63         0         0.817  0.8060    6    -4.606     1
# 2              52         0         0.760  0.8350    5    -8.715     1
# 3               2         0         0.581  0.9370   11    -6.974     1
# 4               5         0         0.417  0.8050    4    -2.919     0
# ...           ...       ...           ...     ...  ...       ...   ...
# 90858          53         0         0.664  0.7780    2    -6.700     1
# 90859          62         0         0.596  0.5800    7    -6.861     1
# 90860           0         0         0.447  0.0075    5   -33.372     1
# 90861          58         0         0.732  0.4600    0    -8.629     1
# 90862           1         0         0.704  0.3330   11   -15.172     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
cluster_grouped=c_zero_four.groupby('Assignments').mean()
cluster_grouped.to_csv("cluster_tableau_test.csv")

# %%
maxValues = cluster_grouped.max()
maxValues
# Out:
# popularity           60.603255
# explicit              0.200625
# danceability          0.665061
# energy                0.653578
# key                   5.346487
# loudness             -7.318606
# mode                  0.683774
# speechiness           0.124723
# acousticness          0.815600
# instrumentalness      0.287498
# liveness              0.226396
# valence               0.552344
# tempo               144.920547
# time_signature        3.961612
# dtype: float64

# %%
# Cluster 0:
#      Higher values: Valence 0.552, Acousticness, Tempo
#      Lower  values: Speechiness, Popularity
# Cluster 1:
#      Higher values: Acousticness,
#      Lower  values: Tempo, Valence, Loudness
# Cluster 2:
#      Higher values: Danceability, Energy, Popularity, Loudness, Valence, Explicitness
#      Lower  values: Instrumentalness, Speechiness,
# Cluster 3:
#      Higher values: Danceability, Energy, Popularity, Loudness, Valence, Tempo
#      Lower  values: Acousticness, Instrumentalness, Speechiness
# Cluster 4:
#      Higher values: Danceability, Energy, Loudness, Valence, Tempo
#      Lower  values: Acousticness, Instrumentalness, Speechiness

# %%
c_five_nine = pd.read_csv("../../Jake/azure_20Clusters_5thru9.csv")
c_five_nine
# Out:
#                                                id_artists  \
# 0                              ['74T1WwwA8A9fXkT3jhk49D']
# 1       ['4mwXUEKaW4ftbncf9Hi58l', '1J2VVASYAamtQ3Bt8w...
# 2                              ['5a2EaR3hamoenG9rDuVn8j']
# 3                              ['3EAqVJtaxnPcWYlHXkHcuC']
# 4                              ['6FAeDq0UGuzHeLiUzz45mA']
# ...                                                   ...
# 134301                         ['3Ar1W7H096Z6qSGBMmwSmO']
# 134302                         ['3pO5VjZ4wOHCMBXOvbMISG']
# 134303                         ['6yrBBtqX2gKCHCrZOYBDrB']
# 134304                         ['1eY7YyYjc9jGnsHdJka906']
# 134305                         ['2Sk7Zo0X5D4XupLkQ1PRZx']
#
#                             id                      name  popularity  \
# 0       2Gd1C5gezJ2kS25xDPAqUy                Tento Klub          33
# 1       7mihEEIJbHFASaHwDMNvFq  Race Against Time Part 2          49
# ...

# %%
# Drop the null columns where all values are null
c_five_nine = c_five_nine.dropna(axis='columns', how='all')
# Drop the null rows
c_five_nine = c_five_nine.dropna()
c_five_nine
# Out:
#                                                id_artists  \
# 0                              ['74T1WwwA8A9fXkT3jhk49D']
# 1       ['4mwXUEKaW4ftbncf9Hi58l', '1J2VVASYAamtQ3Bt8w...
# 2                              ['5a2EaR3hamoenG9rDuVn8j']
# 3                              ['3EAqVJtaxnPcWYlHXkHcuC']
# 4                              ['6FAeDq0UGuzHeLiUzz45mA']
# ...                                                   ...
# 134301                         ['3Ar1W7H096Z6qSGBMmwSmO']
# 134302                         ['3pO5VjZ4wOHCMBXOvbMISG']
# 134303                         ['6yrBBtqX2gKCHCrZOYBDrB']
# 134304                         ['1eY7YyYjc9jGnsHdJka906']
# 134305                         ['2Sk7Zo0X5D4XupLkQ1PRZx']
#
#                             id                      name  popularity  \
# 0       2Gd1C5gezJ2kS25xDPAqUy                Tento Klub          33
# 1       7mihEEIJbHFASaHwDMNvFq  Race Against Time Part 2          49
# ...

# %%
null_columns = c_five_nine.columns[c_five_nine.isnull().any()]
c_five_nine[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
c_five_nine = c_five_nine.drop(['id_artists','id','name','release_date','duration_ms','artists','DistancesToClusterCenter no.0', 'DistancesToClusterCenter no.1',
       'DistancesToClusterCenter no.2', 'DistancesToClusterCenter no.3',
       'DistancesToClusterCenter no.4', 'DistancesToClusterCenter no.5',
       'DistancesToClusterCenter no.6', 'DistancesToClusterCenter no.7',
       'DistancesToClusterCenter no.8', 'DistancesToClusterCenter no.9',
       'DistancesToClusterCenter no.10', 'DistancesToClusterCenter no.11',
       'DistancesToClusterCenter no.12', 'DistancesToClusterCenter no.13',
       'DistancesToClusterCenter no.14', 'DistancesToClusterCenter no.15',
       'DistancesToClusterCenter no.16', 'DistancesToClusterCenter no.17',
       'DistancesToClusterCenter no.18', 'DistancesToClusterCenter no.19'], axis=1)

c_five_nine.count()
# Out:
# popularity          134305
# explicit            134305
# danceability        134305
# energy              134305
# key                 134305
# loudness            134305
# mode                134305
# speechiness         134305
# acousticness        134305
# instrumentalness    134305
# liveness            134305
# valence             134305
# tempo               134305
# time_signature      134305
# Assignments         134305
# dtype: int64

# %%
cluster_grouped2=c_five_nine.groupby('Assignments').mean()
cluster_grouped2
# Out:
#              popularity  explicit  danceability    energy       key  \
# Assignments
# 5             24.230162  0.013268      0.610538  0.560520  5.202885
# 6             41.010006  0.078230      0.564303  0.547922  5.279057
# 7             40.614425  0.041067      0.629734  0.638838  5.295043
# 8             25.367937  0.030030      0.596398  0.556307  5.253322
# 9             23.657928  0.022410      0.505148  0.436025  5.123138
#
#               loudness      mode  speechiness  acousticness  instrumentalness  \
# Assignments
# 5           -10.406656  0.662824     0.087844      0.405972          0.080729
# 6            -9.468019  0.640397     0.137381      0.412133          0.064484
# 7            -8.421742  0.643018     0.077238      0.295335          0.069638
# 8           -10.288167  0.652563     0.103000      0.434327          0.076293
# 9           -12.070894  0.664083     0.153854      0.565923          0.096162
#
#              liveness   valence       tempo  time_signature
# ...

# %%
# Cluster 5:
#      Higher values: Danceability, Energy, Valence, Tempo
#      Lower  values: Instrumentalness, Speechiness
# Cluster 6:
#      Higher values: Danceability, Energy, Loudness
#      Lower  values: Tempo, Instrumentalness
# Cluster 7:
#      Higher values: Danceability, Energy, Loudness, Valence, Tempo
#      Lower  values: Instrumentalness, Acousticness, Speechiness
# Cluster 8:
#      Higher values: Danceability, Valence
#      Lower  values: Loudness
# Cluster 9:
#      Higher values: Speechiness, Acousticness
#      Lower  values: Loudness, Valence, Tempo
